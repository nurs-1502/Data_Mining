# %%
import pandas as pd
from pathlib import Path


from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import matplotlib as mlp
from math import sqrt
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from statsmodels.tsa.deterministic import CalendarFourier, DeterministicProcess
from xgboost import XGBRegressor
import xgboost as xgb
from tensorflow import keras
from scipy import stats


from sklearn.linear_model import ElasticNet, Lasso
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package learntools

# %%
BATCH_SIZE = 32
WINDOW_SIZE = 32
EPOCHS = 100
START = '2017'
END = '2017'

# %% [markdown]
# Reading Data

# %%
oil_df = pd.read_csv( 'oil.csv')
holidays_events_df = pd.read_csv( 'holidays_events.csv')
stores_df = pd.read_csv( 'stores.csv')
train_df = pd.read_csv( 'train.csv')
test_df = pd.read_csv('test.csv')
transactions_df = pd.read_csv('transactions.csv')

# %% [markdown]
# Preprocessing

# %%
train_df = pd.read_csv( 'train.csv',
    usecols=['store_nbr', 'family', 'date', 'sales', 'onpromotion'],
    dtype={
        'store_nbr': 'category',
        'family': 'category',
        'sales': 'float32',
    },
    parse_dates=['date'],
    infer_datetime_format=True,
)

train_df['date'] = train_df.date.dt.to_period('D')
train_df['item'] = "S" + train_df['store_nbr'].astype(str) + "_" + train_df['family'].astype(str)
df = train_df.pivot(index='date', columns='item', values='sales')
train_df = train_df.set_index(['date']).sort_index()
train_df.head(10)
# Out:
# <ipython-input-5-f046194385f0>:1: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   train_df = pd.read_csv( 'train.csv',
#            store_nbr        family  sales  onpromotion             item
# date
# 2013-01-01         1    AUTOMOTIVE    0.0            0    S1_AUTOMOTIVE
# 2013-01-01         1     BABY CARE    0.0            0     S1_BABY CARE
# 2013-01-01         1        BEAUTY    0.0            0        S1_BEAUTY
# 2013-01-01         1     BEVERAGES    0.0            0     S1_BEVERAGES
# 2013-01-01         1         BOOKS    0.0            0         S1_BOOKS
# 2013-01-01         1  BREAD/BAKERY    0.0            0  S1_BREAD/BAKERY
# 2013-01-01         1   CELEBRATION    0.0            0   S1_CELEBRATION
# 2013-01-01         1      CLEANING    0.0            0      S1_CLEANING
# 2013-01-01         1         DAIRY    0.0            0         S1_DAIRY
# 2013-01-01         1          DELI    0.0            0          S1_DELI

# %%
df_test = pd.read_csv(
    'test.csv',
    dtype={
        'store_nbr': 'category',
        'family': 'category',
        'onpromotion': 'uint32',
    },
    parse_dates=['date'],
    infer_datetime_format=True,
)

df_test['date'] = df_test.date.dt.to_period('D')
df_test['item'] = "S" + df_test['store_nbr'].astype(str) + "_" + df_test['family'].astype(str)
df_test = df_test.set_index(['date']).sort_index()
df_test.head(10)
# Out:
# <ipython-input-6-0a6d5f1af6ef>:1: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df_test = pd.read_csv(
#                  id store_nbr        family  onpromotion             item
# date
# 2017-08-16  3000888         1    AUTOMOTIVE            0    S1_AUTOMOTIVE
# 2017-08-16  3000889         1     BABY CARE            0     S1_BABY CARE
# 2017-08-16  3000890         1        BEAUTY            2        S1_BEAUTY
# 2017-08-16  3000891         1     BEVERAGES           20     S1_BEVERAGES
# 2017-08-16  3000892         1         BOOKS            0         S1_BOOKS
# 2017-08-16  3000893         1  BREAD/BAKERY           12  S1_BREAD/BAKERY
# 2017-08-16  3000894         1   CELEBRATION            0   S1_CELEBRATION
# 2017-08-16  3000895         1      CLEANING           25      S1_CLEANING
# 2017-08-16  3000896         1         DAIRY           45         S1_DAIRY
# 2017-08-16  3000897         1          DELI           18          S1_DELI

# %%
holidays_events = pd.read_csv(
    "holidays_events.csv",
    dtype={
        'type': 'category',
        'locale': 'category',
        'locale_name': 'category',
        'description': 'category',
        'transferred': 'bool',
    },
    parse_dates=['date'],
    infer_datetime_format=True,
)

holidays_events = holidays_events.set_index('date').to_period('D')
holidays_events.head(10)
# Out:
# <ipython-input-7-6e210f9734a9>:1: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   holidays_events = pd.read_csv(
#                type    locale locale_name                    description  \
# date
# 2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
# 2012-05-12  Holiday     Local        Puyo         Cantonizacion del Puyo
# 2012-06-23  Holiday     Local    Guaranda      Cantonizacion de Guaranda
# 2012-06-25  Holiday  Regional    Imbabura  Provincializacion de Imbabura
# 2012-06-25  Holiday     Local   Latacunga     Cantonizacion de Latacunga
# 2012-06-25  Holiday     Local     Machala           Fundacion de Machala
#
#             transferred
# date
# 2012-03-02        False
# 2012-04-01        False
# 2012-04-12        False
# 2012-04-14        False
# 2012-04-21        False
# 2012-05-12        False
# 2012-06-23        False
# 2012-06-25        False
# 2012-06-25        False
# 2012-06-25        False

# %% [markdown]
# Handling Missing Dates

# %%
# Create a list of dates
missing_dates = ['2013-12-25', '2014-12-25', '2015-12-25', '2016-12-25']

# Convert the list of dates to datetime objects with a specified format
date_objects = pd.to_datetime(missing_dates, format='%Y-%m-%d')

# Create a DataFrame with a single column named 'Date' containing the datetime objects
missing_df = pd.DataFrame({'date': date_objects})
missing_df['date'] = missing_df.date.dt.to_period('D')
missing_df = missing_df.set_index(['date']).sort_index()

# Concate with the main dataset
df = pd.concat([df, missing_df])
df.fillna(0, inplace=True)
df.sort_index(inplace=True)
df = df.rename_axis("item", axis="columns")
df.head(10)
# Out:
# item        S10_AUTOMOTIVE  S10_BABY CARE  S10_BEAUTY  S10_BEVERAGES  \
# date
# 2013-01-01             0.0            0.0         0.0            0.0
# 2013-01-02             3.0            0.0         6.0          396.0
# 2013-01-03             2.0            0.0         3.0          399.0
# 2013-01-04             2.0            0.0         4.0          460.0
# 2013-01-05             0.0            0.0         3.0          624.0
# 2013-01-06             0.0            0.0         2.0          615.0
# 2013-01-07             6.0            0.0         3.0          461.0
# 2013-01-08             2.0            0.0         2.0          396.0
# 2013-01-09             3.0            0.0         0.0          348.0
# 2013-01-10             4.0            0.0         1.0          401.0
#
# item        S10_BOOKS  S10_BREAD/BAKERY  S10_CELEBRATION  S10_CLEANING  \
# date
# 2013-01-01        0.0               0.0              0.0           0.0
# 2013-01-02        0.0             151.0              0.0        1110.0
# 2013-01-03        0.0             129.0              0.0         970.0
# 2013-01-04        0.0             105.0              0.0         669.0
# 2013-01-05        0.0             112.0              0.0        1093.0
# 2013-01-06        0.0             125.0              0.0        1122.0
# 2013-01-07        0.0             125.0              0.0         816.0
# 2013-01-08        0.0             105.0              0.0         674.0
# 2013-01-09        0.0              82.0              0.0         543.0
# 2013-01-10        0.0              84.0              0.0         680.0
#
# item        S10_DAIRY  S10_DELI  ...  S9_MAGAZINES    S9_MEATS  \
# date                             ...
# 2013-01-01        0.0       0.0  ...           0.0    0.000000
# 2013-01-02      101.0     276.0  ...           0.0  374.531006
# 2013-01-03      113.0     269.0  ...           0.0  400.863007
# 2013-01-04       66.0      92.0  ...           0.0  310.877991
# 2013-01-05       88.0     194.0  ...           0.0  447.684998
# 2013-01-06      109.0     312.0  ...           0.0  555.051025
# 2013-01-07       71.0     180.0  ...           0.0  305.082001
# 2013-01-08       72.0     138.0  ...           0.0  352.997009
# 2013-01-09       73.0     139.0  ...           0.0  335.311005
# 2013-01-10       71.0     117.0  ...           0.0  434.250000
#
# item        S9_PERSONAL CARE  S9_PET SUPPLIES  S9_PLAYERS AND ELECTRONICS  \
# date
# 2013-01-01               0.0              0.0                         0.0
# 2013-01-02             482.0              0.0                         0.0
# 2013-01-03             372.0              0.0                         0.0
# 2013-01-04             324.0              0.0                         0.0
# 2013-01-05             461.0              0.0                         0.0
# 2013-01-06             618.0              0.0                         0.0
# 2013-01-07             358.0              0.0                         0.0
# 2013-01-08             338.0              0.0                         0.0
# 2013-01-09             234.0              0.0                         0.0
# 2013-01-10             236.0              0.0                         0.0
#
# item        S9_POULTRY  S9_PREPARED FOODS  S9_PRODUCE  \
# date
# 2013-01-01    0.000000                0.0         0.0
# 2013-01-02  651.291992               83.0         0.0
# 2013-01-03  509.496002               66.0         0.0
# 2013-01-04  332.671997               57.0         0.0
# 2013-01-05  510.919006               84.0         0.0
# 2013-01-06  604.244019               82.0         0.0
# 2013-01-07  435.082001               31.0         0.0
# 2013-01-08  372.350983               26.0         0.0
# 2013-01-09  317.420990               24.0         0.0
# 2013-01-10  351.544006               69.0         0.0
#
# item        S9_SCHOOL AND OFFICE SUPPLIES  S9_SEAFOOD
# date
# 2013-01-01                            0.0    0.000000
# 2013-01-02                            0.0   29.214001
# 2013-01-03                            0.0   25.000000
# 2013-01-04                            0.0   11.000000
# 2013-01-05                            0.0   28.361000
# 2013-01-06                            0.0   36.553001
# 2013-01-07                            0.0   18.444000
# 2013-01-08                            0.0   25.000000
# 2013-01-09                            0.0   13.484000
# 2013-01-10                            0.0   25.214001
#
# [10 rows x 1782 columns]

# %% [markdown]
# Extracting and Encoding

# %%
# National and regional holidays in the training set
holidays = (
    holidays_events
    .query("locale in ['National', 'Regional']")
    .loc['2016':'2017-08-16', ['description']]
    .assign(description=lambda x: x.description.cat.remove_unused_categories())
)

holidays = pd.get_dummies(holidays, dtype=float)
holidays_train, holidays_test = holidays[:"2017-08-01"], holidays["2017-08-01":"2017-08-15"]

display(holidays_test)
# Out:
#             description_Batalla de Pichincha  description_Black Friday  \
# date
# 2017-08-10                               0.0                       0.0
# 2017-08-11                               0.0                       0.0
#
#             description_Carnaval  description_Cyber Monday  \
# date
# 2017-08-10                   0.0                       0.0
# 2017-08-11                   0.0                       0.0
#
#             description_Dia de Difuntos  description_Dia de la Madre  \
# date
# 2017-08-10                          0.0                          0.0
# 2017-08-11                          0.0                          0.0
#
#             description_Dia de la Madre-1  description_Dia del Trabajo  \
# date
# 2017-08-10                            0.0                          0.0
# 2017-08-11                            0.0                          0.0
#
#             description_Independencia de Cuenca  \
# date
# 2017-08-10                                  0.0
# 2017-08-11                                  0.0
#
#             description_Independencia de Guayaquil  ...  \
# date                                                ...
# 2017-08-10                                     0.0  ...
# 2017-08-11                                     0.0  ...
#
#             description_Terremoto Manabi+4  description_Terremoto Manabi+5  \
# date
# 2017-08-10                             0.0                             0.0
# 2017-08-11                             0.0                             0.0
#
#             description_Terremoto Manabi+6  description_Terremoto Manabi+7  \
# date
# 2017-08-10                             0.0                             0.0
# 2017-08-11                             0.0                             0.0
#
#             description_Terremoto Manabi+8  description_Terremoto Manabi+9  \
# date
# 2017-08-10                             0.0                             0.0
# 2017-08-11                             0.0                             0.0
#
#             description_Traslado Batalla de Pichincha  \
# date
# 2017-08-10                                        0.0
# 2017-08-11                                        0.0
#
#             description_Traslado Primer Grito de Independencia  \
# date
# 2017-08-10                                                0.0
# 2017-08-11                                                1.0
#
#             description_Traslado Primer dia del ano  description_Viernes Santo
# date
# 2017-08-10                                      0.0                        0.0
# 2017-08-11                                      0.0                        0.0
#
# [2 rows x 60 columns]

# %%
zero_sales = list(df.loc[:, (df == 0).all()].columns)
train_df['available'] = np.where(train_df['item'].isin(zero_sales), 0, 1)
df_test['available'] = np.where(df_test['item'].isin(zero_sales), 0, 1)

# %%
df
# Out:
# item        S10_AUTOMOTIVE  S10_BABY CARE  S10_BEAUTY  S10_BEVERAGES  \
# date
# 2013-01-01             0.0            0.0         0.0            0.0
# 2013-01-02             3.0            0.0         6.0          396.0
# 2013-01-03             2.0            0.0         3.0          399.0
# 2013-01-04             2.0            0.0         4.0          460.0
# 2013-01-05             0.0            0.0         3.0          624.0
# ...                    ...            ...         ...            ...
# 2017-08-11             2.0            0.0         2.0         1459.0
# 2017-08-12             2.0            0.0         3.0         1332.0
# 2017-08-13             0.0            0.0         5.0         1526.0
# 2017-08-14             1.0            0.0         6.0         1129.0
# 2017-08-15             4.0            0.0         4.0         1608.0
#
# item        S10_BOOKS  S10_BREAD/BAKERY  S10_CELEBRATION  S10_CLEANING  \
# date
# 2013-01-01        0.0               0.0              0.0           0.0
# 2013-01-02        0.0             151.0              0.0        1110.0
# 2013-01-03        0.0             129.0              0.0         970.0
# 2013-01-04        0.0             105.0              0.0         669.0
# 2013-01-05        0.0             112.0              0.0        1093.0
# ...               ...               ...              ...           ...
# 2017-08-11        0.0              76.0              5.0         532.0
# 2017-08-12        0.0             113.0              5.0         676.0
# 2017-08-13        0.0             119.0              6.0         670.0
# 2017-08-14        0.0              82.0              3.0         710.0
# 2017-08-15        0.0             112.0              2.0         731.0
#
# item        S10_DAIRY  S10_DELI  ...  S9_MAGAZINES    S9_MEATS  \
# date                             ...
# 2013-01-01        0.0       0.0  ...           0.0    0.000000
# 2013-01-02      101.0     276.0  ...           0.0  374.531006
# 2013-01-03      113.0     269.0  ...           0.0  400.863007
# 2013-01-04       66.0      92.0  ...           0.0  310.877991
# 2013-01-05       88.0     194.0  ...           0.0  447.684998
# ...               ...       ...  ...           ...         ...
# 2017-08-11      251.0     269.0  ...           5.0  309.244995
# 2017-08-12      255.0     276.0  ...           2.0  260.298004
# 2017-08-13      270.0     251.0  ...           3.0  327.205994
# 2017-08-14      253.0     313.0  ...          12.0  330.975006
# 2017-08-15      328.0     175.0  ...          11.0  449.227997
#
# item        S9_PERSONAL CARE  S9_PET SUPPLIES  S9_PLAYERS AND ELECTRONICS  \
# date
# 2013-01-01               0.0              0.0                         0.0
# 2013-01-02             482.0              0.0                         0.0
# 2013-01-03             372.0              0.0                         0.0
# 2013-01-04             324.0              0.0                         0.0
# 2013-01-05             461.0              0.0                         0.0
# ...                      ...              ...                         ...
# 2017-08-11             373.0             11.0                         2.0
# 2017-08-12             400.0              7.0                        10.0
# 2017-08-13             510.0              2.0                         9.0
# 2017-08-14             445.0              2.0                        14.0
# 2017-08-15             522.0              6.0                         6.0
#
# item        S9_POULTRY  S9_PREPARED FOODS   S9_PRODUCE  \
# date
# 2013-01-01    0.000000           0.000000     0.000000
# 2013-01-02  651.291992          83.000000     0.000000
# 2013-01-03  509.496002          66.000000     0.000000
# 2013-01-04  332.671997          57.000000     0.000000
# 2013-01-05  510.919006          84.000000     0.000000
# ...                ...                ...          ...
# 2017-08-11  525.223999         112.099998  1453.078003
# 2017-08-12  383.386993         129.903992  1419.264038
# 2017-08-13  412.458008         105.168999  1693.607056
# 2017-08-14  283.428986         114.120003  1348.425049
# 2017-08-15  438.132996         154.552994  2419.729004
#
# item        S9_SCHOOL AND OFFICE SUPPLIES  S9_SEAFOOD
# date
# 2013-01-01                            0.0    0.000000
# 2013-01-02                            0.0   29.214001
# 2013-01-03                            0.0   25.000000
# 2013-01-04                            0.0   11.000000
# 2013-01-05                            0.0   28.361000
# ...                                   ...         ...
# 2017-08-11                          140.0   23.830999
# 2017-08-12                          138.0   16.859001
# 2017-08-13                          200.0   20.000000
# 2017-08-14                          182.0   17.000000
# 2017-08-15                          121.0   16.000000
#
# [1688 rows x 1782 columns]

# %%
train_df
# Out:
#            store_nbr                      family        sales  onpromotion  \
# date
# 2013-01-01         1                  AUTOMOTIVE     0.000000            0
# 2013-01-01         1                   BABY CARE     0.000000            0
# 2013-01-01         1                      BEAUTY     0.000000            0
# 2013-01-01         1                   BEVERAGES     0.000000            0
# 2013-01-01         1                       BOOKS     0.000000            0
# ...              ...                         ...          ...          ...
# 2017-08-15         9                     POULTRY   438.132996            0
# 2017-08-15         9              PREPARED FOODS   154.552994            1
# 2017-08-15         9                     PRODUCE  2419.729004          148
# 2017-08-15         9  SCHOOL AND OFFICE SUPPLIES   121.000000            8
# 2017-08-15         9                     SEAFOOD    16.000000            0
#
#                                      item  available
# date
# 2013-01-01                  S1_AUTOMOTIVE          1
# 2013-01-01                   S1_BABY CARE          0
# 2013-01-01                      S1_BEAUTY          1
# 2013-01-01                   S1_BEVERAGES          1
# 2013-01-01                       S1_BOOKS          1
# ...                                   ...        ...
# 2017-08-15                     S9_POULTRY          1
# 2017-08-15              S9_PREPARED FOODS          1
# 2017-08-15                     S9_PRODUCE          1
# 2017-08-15  S9_SCHOOL AND OFFICE SUPPLIES          1
# 2017-08-15                     S9_SEAFOOD          1
#
# [3000888 rows x 6 columns]

# %% [markdown]
# Feature Engineering

# %%
y = df.loc[START:END]

from sklearn import preprocessing


# X_1: Features for Linear Regression
fourier = CalendarFourier(freq='M', order=4)
dp = DeterministicProcess(
    index=y.index,
    constant=True,
    order=1,
    seasonal=True,
    additional_terms=[fourier],
    drop=True,
)

X_1 = dp.in_sample()
X_1['NewYear'] = (X_1.index.dayofyear == 1)


# X_2: Features for XGBoost
X_2 = train_df.drop(['sales', 'store_nbr', 'item'], axis=1).loc[START:END]  # onpromotion feature

# Label encoding for 'family'
le = LabelEncoder()  # from sklearn.preprocessing
le.fit(X_2.family)
X_2['family'] = le.transform(X_2['family'])

# Label encoding for seasonality
X_2["day"] = X_2.index.day  # values are day of the month
X_2 = X_2.join(holidays_train, on='date').fillna(0.0)

y_train, y_valid = y[:"2017-07-01"], y["2017-07-02":]
X1_train, X1_valid = X_1[: "2017-07-01"], X_1["2017-07-02" :]
X2_train, X2_valid = X_2.loc[:"2017-07-01"], X_2.loc["2017-07-02":]

# %%
val_performance = pd.DataFrame()
performance = pd.DataFrame()

# %% [markdown]
# Linear Regression

# %%
model_linear = LinearRegression(fit_intercept=False)
history = model_linear.fit(X1_train, y_train)
y_fit = pd.DataFrame(model_linear.predict(X1_train), index=X1_train.index, columns=y_train.columns)
y_pred = pd.DataFrame(model_linear.predict(X1_valid), index=X1_valid.index, columns=y_valid.columns)

#Record performance:
for i,j,k in zip([0,1],[y_train,y_valid],[y_fit,y_pred]):
    metric = dict()
    metric['MAE'] = mean_absolute_error(j, k)
    metric['MSE'] = mean_squared_error(j, k)
    metric['RMSE'] = sqrt(mean_squared_error(j, k))
    metric['R2'] = r2_score(j, k)
    res = pd.DataFrame([metric])
    res.index = ['Classic_Linear']
    print(res)
    if i == 0:
        val_performance = pd.concat([val_performance, res])
    else:
        performance = pd.concat([performance, res])
# Out:
#                       MAE           MSE        RMSE        R2
# Classic_Linear  60.669719  60307.913637  245.576696  0.441475
#                       MAE           MSE        RMSE        R2
# Classic_Linear  73.219922  67882.505357  260.542713 -3.378452

# %%
train_sizes, train_scores, val_scores = learning_curve(
    model_linear, X1_train, y_train, train_sizes=np.linspace(0.1,0.01,10)[::-1], cv=5, scoring='neg_mean_squared_error')

train_scores_mean = -np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
val_scores_mean = -np.mean(val_scores, axis=1)
val_scores_std = np.std(val_scores, axis=1)

# Plot the learning curve
plt.figure(figsize=(8, 6))
plt.plot(train_sizes, train_scores_mean, 'o-', color='r', label='Training Score')
plt.plot(train_sizes, val_scores_mean, 'o-', color='g', label='Validation Score')
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color='r')
plt.fill_between(train_sizes, val_scores_mean - val_scores_std,
                 val_scores_mean + val_scores_std, alpha=0.2, color='g')
plt.xlabel('Training Set Size')
plt.ylabel('Negative Mean Squared Error')
plt.title('Learning Curve for Linear Regression')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
items = y.columns[107:115]
plot_params = {'xlabel': 'Date', 'ylabel': 'Sales', 'grid': True}

axs = y.loc(axis=1)[items].plot(
    subplots=True, sharex=True, figsize=(20, 15), **plot_params, alpha=0.5)

_ = y_fit.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C0', ax=axs)
_ = y_pred.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C3', ax=axs)
for ax, item in zip(axs, items):
    ax.legend([])
    ax.set_ylabel(item)
# Out:
# <ipython-input-17-240a4d77c110>:7: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes.
#   _ = y_fit.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C0', ax=axs)
# <ipython-input-17-240a4d77c110>:8: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes.
#   _ = y_pred.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C3', ax=axs)

# %% [markdown]
# Lasso

# %%
model_lasso = Lasso(fit_intercept=False)
history = model_lasso.fit(X1_train, y_train)
y_fit = pd.DataFrame(model_lasso.predict(X1_train), index=X1_train.index, columns=y_train.columns)
y_pred = pd.DataFrame(model_lasso.predict(X1_valid), index=X1_valid.index, columns=y_valid.columns)

#Record performance:
for i,j,k in zip([0,1],[y_train,y_valid],[y_fit,y_pred]):
    metric = dict()
    metric['MAE'] = mean_absolute_error(j, k)
    metric['MSE'] = mean_squared_error(j, k)
    metric['RMSE'] = sqrt(mean_squared_error(j, k))
    metric['R2'] = r2_score(j, k)
    res = pd.DataFrame([metric])
    res.index = ['Classic_Lasso']
    print(res)
    if i == 0:
        val_performance = pd.concat([val_performance, res])
    else:
        performance = pd.concat([performance, res])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
#                      MAE           MSE        RMSE        R2
# Classic_Lasso  62.106229  60525.010084  246.018312  0.246957
#                      MAE           MSE       RMSE        R2
# Classic_Lasso  73.884095  67682.700311  260.15899 -4.305998

# %%
train_sizes, train_scores, val_scores = learning_curve(
    model_lasso, X1_train, y_train, train_sizes=np.linspace(0.1,0.01,10)[::-1], cv=5, scoring='neg_mean_squared_error')

train_scores_mean = -np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
val_scores_mean = -np.mean(val_scores, axis=1)
val_scores_std = np.std(val_scores, axis=1)

# Plot the learning curve
plt.figure(figsize=(8, 6))
plt.plot(train_sizes, train_scores_mean, 'o-', color='r', label='Training Score')
plt.plot(train_sizes, val_scores_mean, 'o-', color='g', label='Validation Score')
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color='r')
plt.fill_between(train_sizes, val_scores_mean - val_scores_std,
                 val_scores_mean + val_scores_std, alpha=0.2, color='g')
plt.xlabel('Training Set Size')
plt.ylabel('Negative Mean Squared Error')
plt.title('Learning Curve for Linear Regression')
plt.legend(loc='best')
plt.grid(True)
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.086e+04, tolerance: 8.071e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.588e+04, tolerance: 8.842e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.180e+03, tolerance: 1.290e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.076e+04, tolerance: 7.503e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.163e+03, tolerance: 4.942e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.579e+02, tolerance: 1.237e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.608e+05, tolerance: 1.078e+05
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.033e+03, tolerance: 1.565e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.921e+04, tolerance: 3.941e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.104e+05, tolerance: 4.103e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.146e+03, tolerance: 6.579e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.844e+03, tolerance: 2.347e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.690e+05, tolerance: 9.012e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.302e+04, tolerance: 8.817e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.356e+05, tolerance: 6.570e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.827e+03, tolerance: 1.079e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.017e+04, tolerance: 6.080e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.303e+03, tolerance: 4.175e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.445e+02, tolerance: 1.082e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.382e+05, tolerance: 9.033e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.128e+02, tolerance: 7.193e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.076e+04, tolerance: 3.123e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.253e+04, tolerance: 2.836e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.700e+03, tolerance: 6.582e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.523e+03, tolerance: 1.829e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.050e+02, tolerance: 4.495e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.412e+05, tolerance: 7.413e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.623e+03, tolerance: 1.139e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.783e+04, tolerance: 3.820e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.008e+05, tolerance: 4.516e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.662e+03, tolerance: 1.105e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.498e+03, tolerance: 4.313e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.041e+03, tolerance: 4.918e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.911e+02, tolerance: 1.590e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.099e+04, tolerance: 5.727e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.328e+04, tolerance: 5.721e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.038e+04, tolerance: 7.014e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.272e+03, tolerance: 6.741e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.361e+04, tolerance: 9.103e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.095e+02, tolerance: 7.829e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.186e+04, tolerance: 5.121e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.705e+04, tolerance: 1.532e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.683e+03, tolerance: 3.286e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.610e+03, tolerance: 1.206e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.548e+02, tolerance: 2.219e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.398e+02, tolerance: 2.183e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.296e+04, tolerance: 4.845e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.743e+04, tolerance: 1.571e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.342e+03, tolerance: 1.366e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.155e+03, tolerance: 1.392e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.178e+04, tolerance: 1.640e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.600e+04, tolerance: 2.125e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.570e+03, tolerance: 3.148e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.209e+03, tolerance: 9.761e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.422e+03, tolerance: 5.492e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.673e+03, tolerance: 2.709e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.995e+03, tolerance: 2.232e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.360e+01, tolerance: 2.750e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.194e+03, tolerance: 8.684e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.989e+01, tolerance: 3.391e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.048e+04, tolerance: 6.218e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.589e+01, tolerance: 3.321e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.506e+03, tolerance: 2.036e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.008e+04, tolerance: 5.122e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.944e+03, tolerance: 1.408e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.008e+04, tolerance: 1.403e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.848e+03, tolerance: 1.370e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.317e+04, tolerance: 2.032e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.545e+04, tolerance: 5.822e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.836e+04, tolerance: 1.367e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.161e+03, tolerance: 1.284e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.526e+04, tolerance: 1.179e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.479e+04, tolerance: 2.671e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.366e+04, tolerance: 1.714e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.103e+03, tolerance: 1.419e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.243e+03, tolerance: 1.646e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.399e+04, tolerance: 1.753e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.183e+04, tolerance: 1.930e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.804e+04, tolerance: 1.534e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.175e+03, tolerance: 3.536e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.355e+02, tolerance: 5.326e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.023e+05, tolerance: 3.791e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.351e+02, tolerance: 2.209e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.428e+02, tolerance: 1.113e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.704e+02, tolerance: 1.682e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.916e+03, tolerance: 2.495e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.259e+03, tolerance: 1.318e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.495e+04, tolerance: 6.351e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.955e+04, tolerance: 2.141e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.682e+04, tolerance: 6.342e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.613e+02, tolerance: 4.619e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.096e+05, tolerance: 4.760e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.755e+03, tolerance: 1.740e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.113e+03, tolerance: 2.807e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.140e+03, tolerance: 6.973e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.539e+04, tolerance: 6.600e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.539e+04, tolerance: 2.040e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.934e+04, tolerance: 6.643e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.967e+03, tolerance: 1.760e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.601e+03, tolerance: 1.290e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.713e+04, tolerance: 7.045e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.266e+03, tolerance: 2.489e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.359e+03, tolerance: 8.074e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.802e+04, tolerance: 6.712e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.168e+03, tolerance: 1.321e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.775e+04, tolerance: 3.211e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.068e+04, tolerance: 1.176e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.940e+03, tolerance: 2.067e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.059e+05, tolerance: 3.172e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.861e+03, tolerance: 2.336e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.350e+04, tolerance: 7.911e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.550e+04, tolerance: 9.599e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.836e+03, tolerance: 3.702e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.507e+04, tolerance: 5.663e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.161e+04, tolerance: 1.099e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.741e+04, tolerance: 8.855e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.397e+04, tolerance: 4.152e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.750e+04, tolerance: 5.420e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.052e+04, tolerance: 6.021e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.672e+04, tolerance: 1.378e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.085e+04, tolerance: 2.401e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.254e+03, tolerance: 9.786e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.409e+05, tolerance: 3.164e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.179e+03, tolerance: 1.466e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.020e+04, tolerance: 7.977e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.085e+04, tolerance: 2.175e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.934e+02, tolerance: 4.984e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.571e+04, tolerance: 1.743e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.104e+03, tolerance: 1.770e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.791e+03, tolerance: 1.725e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.503e+04, tolerance: 5.964e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.302e+03, tolerance: 3.133e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.087e+04, tolerance: 4.201e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.889e+03, tolerance: 1.659e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.833e+04, tolerance: 1.126e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.379e+03, tolerance: 1.175e+03
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.759e+03, tolerance: 2.189e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.447e+03, tolerance: 6.013e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.068e+03, tolerance: 4.911e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.789e+05, tolerance: 5.086e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.190e+03, tolerance: 2.438e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.352e+03, tolerance: 4.432e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.567e+03, tolerance: 2.789e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.909e+03, tolerance: 8.301e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.546e+02, tolerance: 2.741e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.003e+04, tolerance: 1.408e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.438e+05, tolerance: 3.668e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.245e+03, tolerance: 1.034e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.007e+04, tolerance: 2.386e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.433e+04, tolerance: 3.409e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.422e+03, tolerance: 1.368e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.185e+03, tolerance: 1.048e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.898e+05, tolerance: 3.067e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.666e+03, tolerance: 5.088e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.602e+03, tolerance: 1.250e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.042e+03, tolerance: 9.546e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.016e+05, tolerance: 5.840e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.139e+05, tolerance: 5.053e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.115e+03, tolerance: 1.250e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.868e+03, tolerance: 3.717e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.028e+03, tolerance: 1.467e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.666e+03, tolerance: 1.841e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.549e+02, tolerance: 6.354e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.986e+03, tolerance: 3.404e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.282e+03, tolerance: 4.828e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.996e+03, tolerance: 3.081e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.481e+03, tolerance: 8.570e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.890e+02, tolerance: 5.509e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.509e+04, tolerance: 4.842e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.560e+05, tolerance: 3.223e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.862e+03, tolerance: 5.881e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.935e+04, tolerance: 7.410e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.520e+03, tolerance: 1.670e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.130e+03, tolerance: 6.521e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.402e+03, tolerance: 1.056e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.462e+05, tolerance: 7.997e+04
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.901e+03, tolerance: 7.192e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.997e+03, tolerance: 4.249e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.983e+03, tolerance: 2.742e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.211e+03, tolerance: 6.212e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.626e+03, tolerance: 3.949e+02
#   model = cd_fast.enet_coordinate_descent(

# %%
items = y.columns[107:115]
plot_params = {'xlabel': 'Date', 'ylabel': 'Sales', 'grid': True}

axs = y.loc(axis=1)[items].plot(
    subplots=True, sharex=True, figsize=(20, 15), **plot_params, alpha=0.5)

_ = y_fit.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C0', ax=axs)
_ = y_pred.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C3', ax=axs)
for ax, item in zip(axs, items):
    ax.legend([])
    ax.set_ylabel(item)
# Out:
# <ipython-input-20-240a4d77c110>:7: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes.
#   _ = y_fit.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C0', ax=axs)
# <ipython-input-20-240a4d77c110>:8: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes.
#   _ = y_pred.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C3', ax=axs)

# %% [markdown]
# Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler

# Feature Scaling
scaler = StandardScaler()
X1_train_scaled = scaler.fit_transform(X1_train)
X1_valid_scaled = scaler.transform(X1_valid)

# Regularization (Ridge Regression)
ridge_model = Ridge(alpha=1.0)  # Adjust alpha as needed
ridge_model.fit(X1_train_scaled, y_train)
y_fit_ridge = pd.DataFrame(ridge_model.predict(X1_train_scaled), index=X1_train.index, columns=y_train.columns)
y_pred_ridge = pd.DataFrame(ridge_model.predict(X1_valid_scaled), index=X1_valid.index, columns=y_valid.columns)

# Performance Evaluation
for i, j, k in zip([0, 1], [y_train, y_valid], [y_fit_ridge, y_pred_ridge]):
    metric = dict()
    metric['MAE'] = mean_absolute_error(j, k)
    metric['MSE'] = mean_squared_error(j, k)
    metric['RMSE'] = sqrt(mean_squared_error(j, k))
    metric['R2'] = r2_score(j, k)
    res = pd.DataFrame([metric])
    res.index = ['Ridge_Regression']
    print(res)
    if i == 0:
        val_performance = pd.concat([val_performance, res])
    else:
        performance = pd.concat([performance, res])
# Out:
#                         MAE           MSE        RMSE        R2
# Ridge_Regression  60.780869  60368.638267  245.700302  0.441354
#                         MAE           MSE        RMSE        R2
# Ridge_Regression  72.844936  67030.894195  258.903253 -3.353927

# %%
train_sizes, train_scores, val_scores = learning_curve(
    ridge_model, X1_train, y_train, train_sizes=np.linspace(0.1,0.01,10)[::-1], cv=5, scoring='neg_mean_squared_error')

train_scores_mean = -np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
val_scores_mean = -np.mean(val_scores, axis=1)
val_scores_std = np.std(val_scores, axis=1)

# Plot the learning curve
plt.figure(figsize=(8, 6))
plt.plot(train_sizes, train_scores_mean, 'o-', color='r', label='Training Score')
plt.plot(train_sizes, val_scores_mean, 'o-', color='g', label='Validation Score')
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.2, color='r')
plt.fill_between(train_sizes, val_scores_mean - val_scores_std,
                 val_scores_mean + val_scores_std, alpha=0.2, color='g')
plt.xlabel('Training Set Size')
plt.ylabel('Negative Mean Squared Error')
plt.title('Learning Curve for Linear Regression')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
items = y.columns[107:115]
plot_params = {'xlabel': 'Date', 'ylabel': 'Sales', 'grid': True}

axs = y.loc(axis=1)[items].plot(
    subplots=True, sharex=True, figsize=(20, 15), **plot_params, alpha=0.5)

_ = y_fit.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C0', ax=axs)
_ = y_pred.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C3', ax=axs)
for ax, item in zip(axs, items):
    ax.legend([])
    ax.set_ylabel(item)
# Out:
# <ipython-input-23-240a4d77c110>:7: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes.
#   _ = y_fit.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C0', ax=axs)
# <ipython-input-23-240a4d77c110>:8: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes.
#   _ = y_pred.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C3', ax=axs)

# %% [markdown]
# Model Performance on Validation and Test Sets

# %%
x = np.arange(len(performance))
width = 0.3
metric_name = 'mean_absolute_error'
val_mae = val_performance['MAE'].tolist()
test_mae = performance['MAE'].tolist()

plt.ylabel('mean_absolute_error')
plt.bar(x - 0.17, val_mae, width, label='Validation')
plt.bar(x + 0.17, test_mae, width, label='Test')
plt.xticks(ticks=x, labels=['Classic_Linear', 'Classic_Lasso', 'Ridge_Regression'],
           rotation=0)
_ = plt.legend()

# %%
x = np.arange(len(performance))
width = 0.3
metric_name = 'mean_squared_error'
val_mae = val_performance['MSE'].tolist()
test_mae = performance['MSE'].tolist()

plt.ylabel('mean_squared_error')
plt.bar(x - 0.17, val_mae, width, label='Validation')
plt.bar(x + 0.17, test_mae, width, label='Test')
plt.xticks(ticks=x, labels=['Classic_Linear','Classic_Lasso', 'Ridge_Regression'],
           rotation=0)
_ = plt.legend()

# %%
x = np.arange(len(performance))
width = 0.3
metric_name = 'root_mean_squared_error'
val_mae = val_performance['RMSE'].tolist()
test_mae = performance['RMSE'].tolist()

plt.ylabel('root_mean_squared_error')
plt.bar(x - 0.17, val_mae, width, label='Validation')
plt.bar(x + 0.17, test_mae, width, label='Test')
plt.xticks(ticks=x, labels=['Classic_Linear','Classic_Lasso', 'Ridge_Regression'],
           rotation=0)
_ = plt.legend()

# %%
print("Training Performance")
print(performance.head())

print("\n\nValidation Performance")
print(val_performance.head())
# Out:
# Training Performance
#                         MAE           MSE        RMSE        R2
# Classic_Linear    73.219922  67882.505357  260.542713 -3.378452
# Classic_Lasso     73.884095  67682.700311  260.158990 -4.305998
# Ridge_Regression  72.844936  67030.894195  258.903253 -3.353927
#
#
# Validation Performance
#                         MAE           MSE        RMSE        R2
# Classic_Linear    60.669719  60307.913637  245.576696  0.441475
# Classic_Lasso     62.106229  60525.010084  246.018312  0.246957
# Ridge_Regression  60.780869  60368.638267  245.700302  0.441354

# %% [markdown]
# Generating Predictions

# %%
# Create features for test set
X1_test = dp.out_of_sample(steps=16)
X1_test.index.name = 'date'
X1_test['NewYear'] = (X1_test.index.dayofyear == 1)

# %%
y_submit = pd.DataFrame(model_linear.predict(X1_test), index=X1_test.index, columns=y.columns)
y_submit = pd.DataFrame(y_submit.stack(['item']))
y_submit = pd.merge(y_submit, df_test, how='inner', on=['date','item']).reset_index()
y_submit.drop(['date', 'item', 'store_nbr', 'family', 'onpromotion','available'], axis=1, inplace=True)
y_submit.columns = ['sales', 'id']
y_submit.to_csv('submission.csv', index=False)

# %%
# xgb_params = {
#     'max_depth':10,           # maximum depth of each tree - try 2 to 10
#     'learning_rate':0.01,    # effect of each tree - try 0.0001 to 0.1
#     'n_estimators':1000,     # number of trees (that is, boosting rounds) - try 1000 to 8000
#     'min_child_weight':1,    # minimum number of houses in a leaf - try 1 to 10
#     'colsample_bytree':0.7,  # fraction of features (columns) per tree - try 0.2 to 1.0
#     'subsample':0.7,         # fraction of instances (rows) per tree - try 0.2 to 1.0
#     'reg_alpha':0.5,         # L1 regularization (like LASSO) - try 0.0 to 10.0
#     'reg_lambda':1.0,        # L2 regularization (like Ridge) - try 0.0 to 10.0
#     'num_parallel_tree':1,
# }

# mlp_params = {
#     'alpha':0.0001,
#     'early_stopping':True,
# }


# mlp_deep_params = {
#     'hidden_layer_sizes':512,
#     'activation':'tanh',
#     'early_stopping':True,
#     'alpha':0.01
# }

# %% [markdown]
# XGBoost Model

# %%
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# Split the data into training and validation sets
X_train, X_valid, y_train, y_valid = train_test_split(X1_train, y_train, test_size=0.2, random_state=42)

# Define XGBoost model parameters
xgb_params = {
    'objective': 'reg:squarederror',
    'n_estimators': 1000,  # Updated: Reduced from 3000 to avoid overfitting
    'learning_rate': 0.05,
    'gamma': 0,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'max_depth': 3,
    'alpha': 10,
    'n_jobs': -1
}

# Create XGBoost regressor object
model_xgb = xgb.XGBRegressor(**xgb_params)

# Train the XGBoost model
model_xgb.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)],
              early_stopping_rounds=50, verbose=500)

# Make predictions on the validation set
y_pred_train = model_xgb.predict(X_train)
y_pred_valid = model_xgb.predict(X_valid)

# Evaluate the model's performance
mae_train = mean_absolute_error(y_train, y_pred_train)
mse_train = mean_squared_error(y_train, y_pred_train)
rmse_train = np.sqrt(mse_train)
r2_train = r2_score(y_train, y_pred_train)

mae_valid = mean_absolute_error(y_valid, y_pred_valid)
mse_valid = mean_squared_error(y_valid, y_pred_valid)
rmse_valid = np.sqrt(mse_valid)
r2_valid = r2_score(y_valid, y_pred_valid)

print("Training set:")
print(f"Mean Absolute Error (MAE): {mae_train}")
print(f"Mean Squared Error (MSE): {mse_train}")
print(f"Root Mean Squared Error (RMSE): {rmse_train}")
print(f"R-squared (R²): {r2_train}")

print("\nValidation set:")
print(f"Mean Absolute Error (MAE): {mae_valid}")
print(f"Mean Squared Error (MSE): {mse_valid}")
print(f"Root Mean Squared Error (RMSE): {rmse_valid}")
print(f"R-squared (R²): {r2_valid}")
# Out:
# [0]	validation_0-rmse:1308.37027	validation_1-rmse:1296.00759
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [285]	validation_0-rmse:106.02468	validation_1-rmse:312.07367
# Training set:
# Mean Absolute Error (MAE): 31.311731338500977
# Mean Squared Error (MSE): 15413.3525390625
# Root Mean Squared Error (RMSE): 124.15052032470703
# R-squared (R²): 0.7092299273466532
#
# Validation set:
# Mean Absolute Error (MAE): 79.74701690673828
# Mean Squared Error (MSE): 97056.71875
# Root Mean Squared Error (RMSE): 311.5392761230469
# R-squared (R²): 0.07426406695649354

# %%
import pandas as pd

# Convert y_pred to a pandas DataFrame and set the index to match y and y_fit
y_pred_df = pd.DataFrame(y_pred, columns=y.columns, index=y_valid.index)

# Plot the data
axs = y.loc(axis=1)[items].plot(
    subplots=True, sharex=True, figsize=(20, 15), **plot_params, alpha=0.5)

_ = y_fit.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C0', ax=axs)
_ = y_pred_df.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C3', ax=axs)
for ax, item in zip(axs, items):
    ax.legend([])
    ax.set_ylabel(item)
# Out:
# <ipython-input-32-eac0311dcdbe>:10: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes.
#   _ = y_fit.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C0', ax=axs)
# <ipython-input-32-eac0311dcdbe>:11: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes.
#   _ = y_pred_df.loc(axis=1)[items].plot(subplots=True, sharex=True, color='C3', ax=axs)

# %%
# y_fit.shape

# %%
# y_pred.shape

# %%
X1_test = dp.out_of_sample(steps=16)
X1_test.index.name = 'date'
X1_test['NewYear'] = (X1_test.index.dayofyear == 1)

# %% [markdown]
# Generating Predictions

# %%
y_submit = pd.DataFrame(model_linear.predict(X1_test), index=X1_test.index, columns=y.columns)
y_submit = pd.DataFrame(y_submit.stack(['item']))
y_submit = pd.merge(y_submit, df_test, how='inner', on=['date','item']).reset_index()
y_submit.drop(['date', 'item', 'store_nbr', 'family', 'onpromotion','available'], axis=1, inplace=True)
y_submit.columns = ['sales', 'id']
y_submit.to_csv('submission.csv', index=False)

# %%
y_submit = pd.DataFrame(model_lasso.predict(X1_test), index=X1_test.index, columns=y.columns)
y_submit = pd.DataFrame(y_submit.stack(['item']))
y_submit = pd.merge(y_submit, df_test, how='inner', on=['date','item']).reset_index()
y_submit.drop(['date', 'item', 'store_nbr', 'family', 'onpromotion','available'], axis=1, inplace=True)
y_submit.columns = ['sales', 'id']
y_submit.to_csv('model_lasso_submission.csv', index=False)

# %%
y_submit = pd.DataFrame(ridge_model.predict(X1_test), index=X1_test.index, columns=y.columns)
y_submit = pd.DataFrame(y_submit.stack(['item']))
y_submit = pd.merge(y_submit, df_test, how='inner', on=['date','item']).reset_index()
y_submit.drop(['date', 'item', 'store_nbr', 'family', 'onpromotion','available'], axis=1, inplace=True)
y_submit.columns = ['sales', 'id']
y_submit.to_csv('ridge_model_submission.csv', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but Ridge was fitted without feature names
#   warnings.warn(

# %%
y_submit = pd.DataFrame(model_xgb.predict(X1_test), index=X1_test.index, columns=y.columns)
y_submit = pd.DataFrame(y_submit.stack(['item']))
y_submit = pd.merge(y_submit, df_test, how='inner', on=['date','item']).reset_index()
y_submit.drop(['date', 'item', 'store_nbr', 'family', 'onpromotion','available'], axis=1, inplace=True)
y_submit.columns = ['sales', 'id']
y_submit.to_csv('model_xgb_submission.csv', index=False)
