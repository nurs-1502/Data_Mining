# %%
try:
    from google.colab import drive
    drive.mount('/content/drive/')
    # %cd 'drive/My Drive/DATA_MINING_PROJECT/'
except ImportError as e:
    pass
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive/DATA_MINING_PROJECT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

import scipy.stats as stats
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from statsmodels.tsa.arima.model import ARIMA

# %%
df_holidays = pd.read_csv('Data_Mining-master/holidays_events.csv', header = 0)
df_oil = pd.read_csv('Data_Mining-master/oil.csv', header = 0)
df_stores = pd.read_csv('Data_Mining-master/stores.csv', header = 0)
df_trans = pd.read_csv('Data_Mining-master/transactions.csv', header = 0)
df_train = pd.read_csv('Data_Mining-master/train.csv', header = 0)
df_test = pd.read_csv('Data_Mining-master/test.csv', header = 0)

# %% [markdown]
# # Part 1. Transactions

# %% [markdown]
# # Which day of the week most of the transactions happened (what is the daily seasonality in transactions)?

# %%
df_trans_copy = df_trans.copy()

# %%
df_trans_copy["date"] = pd.to_datetime(df_trans_copy.date)

# %%
df_trans_copy["year"] = df_trans_copy.date.dt.year
df_trans_copy["dayofweek"] = df_trans_copy.date.dt.dayofweek
df_trans_copy = df_trans_copy.groupby(["year", "dayofweek"]).transactions.sum().reset_index()
df_trans_copy.head()
# Out:
#    year  dayofweek  transactions
# 0  2013          0       4072431
# 1  2013          1       3950674
# 2  2013          2       3859367
# 3  2013          3       3793580
# 4  2013          4       3998777

# %%
px.line(df_trans_copy, x="dayofweek", y="transactions" , color = "year", title = "Transactions")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Create a new column to label weekends (1) and weekdays (0)
df_trans_copy['weekend'] = df_trans_copy['dayofweek'].isin([5, 6]).astype(int)

# Split the dataframe into two groups: weekends and weekdays
weekend_transactions = df_trans_copy[df_trans_copy['weekend'] == 1]['transactions']
weekday_transactions = df_trans_copy[df_trans_copy['weekend'] == 0]['transactions']

# Perform a t-test to compare the mean transactions between weekends and weekdays
t_stat, p_value = stats.ttest_ind(weekend_transactions, weekday_transactions)

# Define significance level
alpha = 0.05

# Print the results
if p_value < alpha:
    print("Reject the null hypothesis. Transactions are significantly higher on weekends.")
else:
    print("Fail to reject the null hypothesis. There's no significant difference in transactions between weekends and weekdays.")
# Out:
# Reject the null hypothesis. Transactions are significantly higher on weekends.

# %% [markdown]
# # Which state has the higest transcations?

# %%
merged_df = pd.merge(df_stores, df_trans, on='store_nbr')
merged_df.head()
# Out:
#    store_nbr   city      state type  cluster        date  transactions
# 0          1  Quito  Pichincha    D       13  2013-01-02          2111
# 1          1  Quito  Pichincha    D       13  2013-01-03          1833
# 2          1  Quito  Pichincha    D       13  2013-01-04          1863
# 3          1  Quito  Pichincha    D       13  2013-01-05          1509
# 4          1  Quito  Pichincha    D       13  2013-01-06           520

# %%
# Group by state and sum transactions
transactions_by_state = merged_df.groupby('state')['transactions'].sum().reset_index()
transactions_by_state.head()
# Out:
#         state  transactions
# 0       Azuay       5673847
# 1     Bolivar       2107489
# 2  Chimborazo       2287850
# 3    Cotopaxi       3531356
# 4      El Oro       3945341

# %%
# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(transactions_by_state['state'], transactions_by_state['transactions'], color='skyblue')

# Adding labels and title
plt.xlabel('State')
plt.ylabel('Number of Transactions')
plt.title('Number of Transactions per State')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Top 10 stores with highest transactions

# %%
# Merge the two DataFrames on the 'store_nbr' column
merged_df = pd.merge(df_stores, df_trans, on='store_nbr')

# Calculate average transactions for each store
average_transactions_per_store = merged_df.groupby('store_nbr')['transactions'].mean().reset_index()

# Rename columns for clarity
average_transactions_per_store.columns = ['store_nbr', 'average_transactions']

# Display the table
print(average_transactions_per_store.head())
# Out:
#    store_nbr  average_transactions
# 0          1           1523.844272
# 1          2           1920.036374
# 2          3           3201.879475
# 3          4           1502.987470
# 4          5           1400.045915

# %%
# Sort values by 'average_transactions' column in ascending order
sorted_df = average_transactions_per_store.sort_values(by='average_transactions', ascending = False)

# Merge with the original DataFrame to retain 'city' and 'state' columns
sorted_df = pd.merge(sorted_df, df_stores[['store_nbr', 'city', 'state']], on='store_nbr')
# Display the sorted DataFrame
print(sorted_df.head(10))
# Out:
#    store_nbr  average_transactions     city       state
# 0         44           4336.966607    Quito   Pichincha
# 1         47           3897.322600    Quito   Pichincha
# 2         45           3697.742993    Quito   Pichincha
# 3         46           3571.921884    Quito   Pichincha
# 4          3           3201.879475    Quito   Pichincha
# 5         48           3045.787120    Quito   Pichincha
# 6          8           2767.285800    Quito   Pichincha
# 7         49           2727.550984    Quito   Pichincha
# 8         50           2614.456768   Ambato  Tungurahua
# 9         11           2370.219570  Cayambe   Pichincha

# %% [markdown]
# # Which store provides most promotions and is there correlation between transactions and promotions?

# %%
# Group by 'store_nbr' and sum 'onpromotion' column
onpromotion_sum_by_store = df_train.groupby('store_nbr')['onpromotion'].sum().reset_index()

# Rename the column for clarity
onpromotion_sum_by_store.columns = ['store_nbr', 'onpromotion_sum']

# Merge with the sorted_df DataFrame
sorted_df = pd.merge(sorted_df, onpromotion_sum_by_store, on='store_nbr', how='left')

# %%
sorted_df.head()
# Out:
#    store_nbr  average_transactions   city      state  onpromotion_sum
# 0         44           4336.966607  Quito  Pichincha           192449
# 1         47           3897.322600  Quito  Pichincha           192725
# 2         45           3697.742993  Quito  Pichincha           191503
# 3         46           3571.921884  Quito  Pichincha           190697
# 4          3           3201.879475  Quito  Pichincha           177075

# %%
# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(sorted_df['onpromotion_sum'], sorted_df['average_transactions'], color='blue', alpha=0.5)

# Add labels and title
plt.xlabel('Total Promotion Count')
plt.ylabel('Average Transactions')
plt.title('Scatter Plot of Average Transactions vs Total Promotion Count')

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### We'll employ the Pearson correlation test to assess the connection between the two numerical variables. This test evaluates the linear relationship between continuous variables, yielding a coefficient between -1 and +1. For the hypotheses: H0 (>0.05): There's no impact of promotion on average transaction. H1 (<0.05): Promotion does impact average transcations.

# %%
correlation, p_value = pearsonr(sorted_df['onpromotion_sum'], sorted_df['average_transactions'])

print("Pearson correlation coefficient:", correlation)
print("p-value:", p_value)
# Out:
# Pearson correlation coefficient: 0.6085818698287779
# p-value: 1.0494271288749209e-06

# %% [markdown]
# # Can removing outliers improve correlation coefficient?

# %%
# Sort the DataFrame by 'onpromotion_sum'
sorted_df = sorted_df.sort_values(by='onpromotion_sum')

# Remove the lowest and highest 'onpromotion_sum' values
filtered_df = sorted_df.iloc[1:-1]

# Create scatter plot with filtered data
plt.figure(figsize=(10, 6))
plt.scatter(filtered_df['onpromotion_sum'], filtered_df['average_transactions'], color='blue', alpha=0.5)

# Add labels and title
plt.xlabel('Total Promotion Count')
plt.ylabel('Average Transactions')
plt.title('Scatter Plot of Average Transactions vs Total Promotion Count (Outliers Removed)')

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
correlation, p_value = pearsonr(filtered_df['onpromotion_sum'], filtered_df['average_transactions'])

print("Pearson correlation coefficient:", correlation)
print("p-value:", p_value)
# Out:
# Pearson correlation coefficient: 0.8250630095130054
# p-value: 5.4193658673550776e-14

# %% [markdown]
# ### Given a Pearson correlation coefficient of 0.825 and a very samll p-value, we reject the null hypothesis (H0) and affirm that there's a significant correlation between promotion and average transcations. Thus, the promotion does indeed impact store transactions.

# %% [markdown]
# # Which product family is on promotion most?

# %%
df_train.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
# Group by 'family' and sum 'onpromotion', then reset index to convert to DataFrame
onpromotion_sum_by_family = df_train.groupby('family')['onpromotion'].sum().reset_index()

# Rename the columns for clarity
onpromotion_sum_by_family.columns = ['family', 'onpromotion_sum']

# Sort the DataFrame by 'onpromotion_sum' in descending order
onpromotion_sum_by_family = onpromotion_sum_by_family.sort_values(by='onpromotion_sum', ascending=False)

# Print the sorted DataFrame
print(onpromotion_sum_by_family)
# Out:
#                         family  onpromotion_sum
# 12                   GROCERY I          1914801
# 30                     PRODUCE          1117921
# 3                    BEVERAGES           906958
# 8                        DAIRY           728707
# 7                     CLEANING           661157
# 9                         DELI           583316
# 5                 BREAD/BAKERY           331289
# 24                       MEATS           304028
# 25               PERSONAL CARE           246928
# 28                     POULTRY           226421
# 18                   HOME CARE           197230
# 10                        EGGS           194922
# 11                FROZEN FOODS           125634
# 15          HOME AND KITCHEN I            46921
# 22            LIQUOR,WINE,BEER            46700
# 32                     SEAFOOD            39052
# 29              PREPARED FOODS            37524
# 16         HOME AND KITCHEN II            32814
# 31  SCHOOL AND OFFICE SUPPLIES            14565
# ...

# %% [markdown]
# # Which month the promotions are most high

# %%
import calendar

# Convert 'date' column to datetime datatype for the df_train DataFrame
df_train['date'] = pd.to_datetime(df_train['date'])

# Extract month from the 'date' column and sum 'onpromotion' for each month
monthly_onpromotion_sum = df_train.groupby(df_train['date'].dt.month)['onpromotion'].sum()

# Plot the bar chart
plt.figure(figsize=(10, 6))
monthly_onpromotion_sum.plot(kind='bar', color='blue', alpha=0.7)

# Add labels and title
plt.title('Total Onpromotion for Each Month')
plt.xlabel('Month')
plt.ylabel('Total Onpromotion')
plt.xticks(range(12), [calendar.month_name[i] for i in range(1, 13)], rotation=45)  # Use month names for x-axis labels

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Part 2. Sales

# %%
df_train.head()
# Out:
#    id       date  store_nbr      family  sales  onpromotion
# 0   0 2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1 2013-01-01          1   BABY CARE    0.0            0
# 2   2 2013-01-01          1      BEAUTY    0.0            0
# 3   3 2013-01-01          1   BEVERAGES    0.0            0
# 4   4 2013-01-01          1       BOOKS    0.0            0

# %% [markdown]
# # Remove stores with zero sales of a particular family of products

# %% [markdown]
# ### Upon initial inspection of our training dataset, it's evident that numerous entries contain zeros. This observation suggests that certain stores may not carry specific products due to their unsuitability for those items. Consequently, we will eliminate these entries, as they should not contribute to sales forecasts.

# %%
# Grouping train DataFrame by specified columns and summing sales
df_zeros = df_train.groupby(['id', 'store_nbr', 'family']).sales.sum().reset_index()

# Filtering out rows where sales are zero
df_zeros = df_zeros[df_zeros.sales == 0]

# Performing an outer merge with train DataFrame
df_join = df_train.merge(df_zeros, on=['id', 'store_nbr', 'family'], how='outer', indicator=True, suffixes=('', '_zeros'))

# Filtering out rows exclusive to train DataFrame
df_train1 = df_join[df_join['_merge'] != 'both']

# Dropping unnecessary columns and resetting index
df_train1 = df_train1.drop(['id', '_merge', 'onpromotion', 'sales_zeros'], axis=1).reset_index(drop=True)
df_train1
# Out:
#               date  store_nbr                      family     sales
# 0       2013-01-01         25                      BEAUTY     2.000
# 1       2013-01-01         25                   BEVERAGES   810.000
# 2       2013-01-01         25                BREAD/BAKERY   180.589
# 3       2013-01-01         25                    CLEANING   186.000
# 4       2013-01-01         25                       DAIRY   143.000
# ...            ...        ...                         ...       ...
# 2061753 2017-08-15          9                     POULTRY   438.133
# 2061754 2017-08-15          9              PREPARED FOODS   154.553
# 2061755 2017-08-15          9                     PRODUCE  2419.729
# 2061756 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 2061757 2017-08-15          9                     SEAFOOD    16.000
#
# [2061758 rows x 4 columns]

# %%
sorted_df
# Out:
#     store_nbr  average_transactions           city  \
# 10         52           2333.838983          Manta
# 52         32            635.197376      Guayaquil
# 49         22            751.350224           Puyo
# 50         30            707.631420      Guayaquil
# 44         10            986.562985          Quito
# 46         13            938.248210      Latacunga
# 51         35            670.578162         Playas
# 53         26            634.719309      Guayaquil
# 33         19           1257.451671       Guaranda
# 26         14           1396.733822       Riobamba
# 45         25            941.400619        Salinas
# 47         16            873.284436  Santo Domingo
# 34         12           1212.160891      Latacunga
# 30         15           1318.554893         Ibarra
# 31         43           1305.236842     Esmeraldas
# 39         42           1114.786111         Cuenca
# 40         23           1066.291592         Ambato
# ...

# %%
# Merge the two DataFrames on the 'store_nbr' column
merged_df1 = pd.merge(df_stores, df_train1, on='store_nbr')
merged_df1
# Out:
#          store_nbr       city      state type  cluster       date  \
# 0                1      Quito  Pichincha    D       13 2013-01-02
# 1                1      Quito  Pichincha    D       13 2013-01-02
# 2                1      Quito  Pichincha    D       13 2013-01-02
# 3                1      Quito  Pichincha    D       13 2013-01-02
# 4                1      Quito  Pichincha    D       13 2013-01-02
# ...            ...        ...        ...  ...      ...        ...
# 2061753         54  El Carmen     Manabi    C        3 2017-08-15
# 2061754         54  El Carmen     Manabi    C        3 2017-08-15
# 2061755         54  El Carmen     Manabi    C        3 2017-08-15
# 2061756         54  El Carmen     Manabi    C        3 2017-08-15
# 2061757         54  El Carmen     Manabi    C        3 2017-08-15
#
#                           family     sales
# 0                     AUTOMOTIVE     2.000
# 1                         BEAUTY     2.000
# ...

# %% [markdown]
# ##Average sales by store

# %%
# Calculate average sales for each store
average_sales_per_store = merged_df1.groupby('store_nbr')['sales'].mean().reset_index()

# Rename columns for clarity
average_sales_per_store.columns = ['store_nbr', 'average_sales_store']

# Merge with the sorted_df DataFrame to add average sales by store
sorted_df = pd.merge(sorted_df, average_sales_per_store, on='store_nbr')
sorted_df
# Out:
#     store_nbr  average_transactions           city  \
# 0          52           2333.838983          Manta
# 1          32            635.197376      Guayaquil
# 2          22            751.350224           Puyo
# 3          30            707.631420      Guayaquil
# 4          10            986.562985          Quito
# 5          13            938.248210      Latacunga
# 6          35            670.578162         Playas
# 7          26            634.719309      Guayaquil
# 8          19           1257.451671       Guaranda
# 9          14           1396.733822       Riobamba
# 10         25            941.400619        Salinas
# 11         16            873.284436  Santo Domingo
# 12         12           1212.160891      Latacunga
# 13         15           1318.554893         Ibarra
# 14         43           1305.236842     Esmeraldas
# 15         42           1114.786111         Cuenca
# 16         23           1066.291592         Ambato
# ...

# %%
# Merge sorted_df with merged_df to add the 'family' column
sorted_df = pd.merge(sorted_df, merged_df1[['store_nbr', 'family']], on='store_nbr', how='left')
sorted_df
# Out:
#          store_nbr  average_transactions   city   state  onpromotion_sum  \
# 0               52           2333.838983  Manta  Manabi            30814
# 1               52           2333.838983  Manta  Manabi            30814
# 2               52           2333.838983  Manta  Manabi            30814
# 3               52           2333.838983  Manta  Manabi            30814
# 4               52           2333.838983  Manta  Manabi            30814
# ...            ...                   ...    ...     ...              ...
# 2061753         53           1011.209940  Manta  Manabi           204016
# 2061754         53           1011.209940  Manta  Manabi           204016
# 2061755         53           1011.209940  Manta  Manabi           204016
# 2061756         53           1011.209940  Manta  Manabi           204016
# 2061757         53           1011.209940  Manta  Manabi           204016
#
#          average_sales_store                   family
# ...

# %%
sorted_df
# Out:
#          store_nbr  average_transactions   city   state  onpromotion_sum  \
# 0               52           2333.838983  Manta  Manabi            30814
# 1               52           2333.838983  Manta  Manabi            30814
# 2               52           2333.838983  Manta  Manabi            30814
# 3               52           2333.838983  Manta  Manabi            30814
# 4               52           2333.838983  Manta  Manabi            30814
# ...            ...                   ...    ...     ...              ...
# 2061753         53           1011.209940  Manta  Manabi           204016
# 2061754         53           1011.209940  Manta  Manabi           204016
# 2061755         53           1011.209940  Manta  Manabi           204016
# 2061756         53           1011.209940  Manta  Manabi           204016
# 2061757         53           1011.209940  Manta  Manabi           204016
#
#          average_sales_store                   family
# ...

# %% [markdown]
# ##Is there correlation between promotion and sales?

# %%
# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(sorted_df['onpromotion_sum'], sorted_df['average_sales_store'], color='blue', alpha=0.5)

# Add labels and title
plt.xlabel('Total Promotion Count')
plt.ylabel('Average Sales')
plt.title('Scatter Plot of Average Sales vs Total Promotion Count')

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
correlation, p_value = pearsonr(sorted_df['onpromotion_sum'], sorted_df['average_sales_store'])

print("Pearson correlation coefficient:", correlation)
print("p-value:", p_value)
# Out:
# Pearson correlation coefficient: 0.7796423340973779
# p-value: 0.0

# %%
#Sort the DataFrame by 'onpromotion_sum'
sorted_df = sorted_df.sort_values(by='onpromotion_sum')

# Remove the lowest and highest 'onpromotion_sum' values
filtered_df1 = sorted_df.iloc[1:-1]

# Create scatter plot with filtered data
plt.figure(figsize=(10, 6))
plt.scatter(filtered_df1['onpromotion_sum'], filtered_df1['average_sales_store'], color='blue', alpha=0.5)

# Add labels and title
plt.xlabel('Total Promotion Count')
plt.ylabel('Average Sales')
plt.title('Scatter Plot of Average Sales vs Total Promotion Count (Outliers Removed)')

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
correlation, p_value = pearsonr(filtered_df1['onpromotion_sum'], filtered_df1['average_sales_store'])

print("Pearson correlation coefficient:", correlation)
print("p-value:", p_value)
# Out:
# Pearson correlation coefficient: 0.7796487638416745
# p-value: 0.0

# %% [markdown]
# ##Which day of the week most of the sales happened (what is the daily seasonality in sales)?

# %%
df_train1['date'] = pd.to_datetime(df_train1['date'])

# Extract the day of the week and year
df_train1['year'] = df_train1['date'].dt.year
df_train1['day_of_week'] = df_train1['date'].dt.dayofweek

# Group by day of the week and sum the sales
sales_by_day = df_train1.groupby(['year', 'day_of_week'])['sales'].sum().reset_index()
# Print the DataFrame with sales values displayed without scientific notation
pd.options.display.float_format = '{:.2f}'.format

sales_by_day.head()
# Out:
#    year  day_of_week       sales
# 0  2013            0 19574545.00
# 1  2013            1 17589306.20
# 2  2013            2 17473797.42
# 3  2013            3 16085019.90
# 4  2013            4 18082197.14

# %% [markdown]
# ##Interpretations is that from the line graph on the 6th day of the week has highest sales

# %%
px.line(sales_by_day, x="day_of_week", y="sales" , color = "year", title = "Sales")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Sales are significantly higher on weekends.

# %%
# Create a new column to label weekends (1) and weekdays (0)
df_train1['weekend'] = df_train1['day_of_week'].isin([5, 6]).astype(int)

# Split the dataframe into two groups: weekends and weekdays
weekend_sales = df_train1[df_train1['weekend'] == 1]['sales']
weekday_sales = df_train1[df_train1['weekend'] == 0]['sales']

# Perform a t-test to compare the mean sales between weekends and weekdays
t_stat, p_value = stats.ttest_ind(weekend_sales, weekday_sales)

# Define significance level
alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis. Sales are significantly higher on weekends.")
else:
    print("Fail to reject the null hypothesis. There's no significant difference in sales between weekends and weekdays.")
# Out:
# Reject the null hypothesis. Sales are significantly higher on weekends.

# %% [markdown]
# ##Total sales by week

# %%
from matplotlib.ticker import FuncFormatter
# Extract week number from the 'date' column using ISO calendar
df_train1['week'] = df_train1['date'].dt.isocalendar().week

# Group by week and calculate total sales for each week
sales_by_week = df_train1.groupby('week')['sales'].sum().reset_index()

# Plot total sales by week
plt.figure(figsize=(10, 6))
plt.plot(sales_by_week['week'], sales_by_week['sales'], marker='o', linestyle='-')
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: '{:.0f}M'.format(x / 1e6)))
plt.xlabel('Week Number')
plt.ylabel('Total Sales')
plt.title('Total Sales by Week')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Total Sales by Year

# %%
from matplotlib.ticker import FuncFormatter
# Extract year from the 'date' column
df_train1['year'] = df_train1['date'].dt.year

# Group by year and calculate total sales for each year
sales_by_year = df_train1.groupby('year')['sales'].sum().reset_index()

# Plot total sales by year
plt.figure(figsize=(10, 6))
plt.bar(sales_by_year['year'], sales_by_year['sales'], color='skyblue')
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: '{:.0f}M'.format(x / 1e6)))
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.title('Total Sales by Year')
plt.xticks(sales_by_year['year'])
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# Group by state and sum transactions
sales_by_state = merged_df1.groupby('state')['sales'].sum().reset_index()
sales_by_state
# Out:
#                              state        sales
# 0                            Azuay  49168596.03
# 1                          Bolivar  13049509.84
# 2                       Chimborazo  11387918.75
# 3                         Cotopaxi  21182263.78
# 4                           El Oro  33386796.54
# 5                       Esmeraldas  16391692.21
# 6                           Guayas 165154392.38
# 7                         Imbabura  11451270.02
# 8                             Loja  18859999.26
# 9                         Los Rios  31925373.99
# 10                          Manabi  24969820.13
# 11                         Pastaza   4090201.74
# 12                       Pichincha 585067395.31
# 13                     Santa Elena  11420997.87
# 14  Santo Domingo de los Tsachilas  35834323.04
# 15                      Tungurahua  40304401.30

# %%
# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(sales_by_state['state'], sales_by_state['sales'], color='skyblue')

# Adding labels and title
plt.xlabel('State')
plt.ylabel('Total Sales')
plt.title('Sales per State')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show plot
plt.tight_layout()
plt.show()

# %%
merged_df1
# Out:
#          store_nbr       city      state type  cluster       date  \
# 0                1      Quito  Pichincha    D       13 2013-01-02
# 1                1      Quito  Pichincha    D       13 2013-01-02
# 2                1      Quito  Pichincha    D       13 2013-01-02
# 3                1      Quito  Pichincha    D       13 2013-01-02
# 4                1      Quito  Pichincha    D       13 2013-01-02
# ...            ...        ...        ...  ...      ...        ...
# 2061753         54  El Carmen     Manabi    C        3 2017-08-15
# 2061754         54  El Carmen     Manabi    C        3 2017-08-15
# 2061755         54  El Carmen     Manabi    C        3 2017-08-15
# 2061756         54  El Carmen     Manabi    C        3 2017-08-15
# 2061757         54  El Carmen     Manabi    C        3 2017-08-15
#
#                           family   sales
# 0                     AUTOMOTIVE    2.00
# 1                         BEAUTY    2.00
# 2                      BEVERAGES 1091.00
# ...

# %% [markdown]
# ##How many stores per State?

# %%
# Group the DataFrame by 'state' and count the unique values in 'store_nbr'
stores_per_state = merged_df1.groupby('state')['store_nbr'].nunique().reset_index()

# Rename the columns for clarity
stores_per_state.columns = ['State', 'Number of Stores']

stores_per_state
# Out:
#                              State  Number of Stores
# 0                            Azuay                 3
# 1                          Bolivar                 1
# 2                       Chimborazo                 1
# 3                         Cotopaxi                 2
# 4                           El Oro                 2
# 5                       Esmeraldas                 1
# 6                           Guayas                11
# 7                         Imbabura                 1
# 8                             Loja                 1
# 9                         Los Rios                 2
# 10                          Manabi                 3
# 11                         Pastaza                 1
# 12                       Pichincha                19
# 13                     Santa Elena                 1
# 14  Santo Domingo de los Tsachilas                 3
# 15                      Tungurahua                 2

# %% [markdown]
# ##which state has highest sales and list all states from highest to lowest sales?

# %%
# Group by state and sum the sales for each state
sales_by_state = merged_df1.groupby('state')['sales'].sum().reset_index()

# Find the state with the highest total sales
state_with_highest_sales = sales_by_state[sales_by_state['sales'] == sales_by_state['sales'].max()]

# Display the state with the highest sales
print("State with the highest sales:")
print(state_with_highest_sales)

# Sort states by sales from highest to lowest
sorted_states_by_sales = sales_by_state.sort_values(by='sales', ascending=False)

sorted_states_by_sales
# Out:
# State with the highest sales:
#         state        sales
# 12  Pichincha 585067395.31
#                              state        sales
# 12                       Pichincha 585067395.31
# 6                           Guayas 165154392.38
# 0                            Azuay  49168596.03
# 15                      Tungurahua  40304401.30
# 14  Santo Domingo de los Tsachilas  35834323.04
# 4                           El Oro  33386796.54
# 9                         Los Rios  31925373.99
# 10                          Manabi  24969820.13
# 3                         Cotopaxi  21182263.78
# 8                             Loja  18859999.26
# 5                       Esmeraldas  16391692.21
# 1                          Bolivar  13049509.84
# 7                         Imbabura  11451270.02
# 13                     Santa Elena  11420997.87
# 2                       Chimborazo  11387918.75
# 11                         Pastaza   4090201.74

# %% [markdown]
# ##Which family has highest Sales?
# ###Interpretations: According to the 1. Product_family= "Grocery-I" has "highest" sales probably reason for I guess there are spent highest promotion on "Grocery-I".
# ###2. Productfamily= "Books" has "lowest sales" because there are not promoting the books(there is 0 spent onpromotion for books).

# %%
# Group by 'family' and sum 'sales' column
sales_by_family = df_train.groupby('family')['sales'].sum().reset_index()

# Sort the DataFrame by 'sales' column in descending order
sorted_sales_by_family = sales_by_family.sort_values(by='sales', ascending=False)

sorted_sales_by_family
# Out:
#                         family        sales
# 12                   GROCERY I 343462734.89
# 3                    BEVERAGES 216954486.00
# 30                     PRODUCE 122704684.68
# 7                     CLEANING  97521289.00
# 8                        DAIRY  64487709.00
# 5                 BREAD/BAKERY  42133945.58
# 28                     POULTRY  31876004.47
# 24                       MEATS  31086468.40
# 25               PERSONAL CARE  24592051.00
# 9                         DELI  24110322.47
# 18                   HOME CARE  16022744.00
# 10                        EGGS  15588296.00
# 11                FROZEN FOODS  14073887.72
# 29              PREPARED FOODS   8799895.12
# 22            LIQUOR,WINE,BEER   7746640.00
# 32                     SEAFOOD   2015431.88
# 13                  GROCERY II   1962767.00
# 15          HOME AND KITCHEN I   1861491.00
# 16         HOME AND KITCHEN II   1520670.00
# 6                  CELEBRATION    761177.00
# ...

# %%
merged_df1
# Out:
#          store_nbr       city      state type  cluster       date  \
# 0                1      Quito  Pichincha    D       13 2013-01-02
# 1                1      Quito  Pichincha    D       13 2013-01-02
# 2                1      Quito  Pichincha    D       13 2013-01-02
# 3                1      Quito  Pichincha    D       13 2013-01-02
# 4                1      Quito  Pichincha    D       13 2013-01-02
# ...            ...        ...        ...  ...      ...        ...
# 2061753         54  El Carmen     Manabi    C        3 2017-08-15
# 2061754         54  El Carmen     Manabi    C        3 2017-08-15
# 2061755         54  El Carmen     Manabi    C        3 2017-08-15
# 2061756         54  El Carmen     Manabi    C        3 2017-08-15
# 2061757         54  El Carmen     Manabi    C        3 2017-08-15
#
#                           family   sales
# 0                     AUTOMOTIVE    2.00
# 1                         BEAUTY    2.00
# 2                      BEVERAGES 1091.00
# ...

# %% [markdown]
# ##For each store which product_family produce/available/sell/sales more in each state?

# %%
# Group the DataFrame by 'state', 'store_nbr', and 'product_family', and aggregate by sales
sales_by_state_store_family = merged_df1.groupby(['state', 'store_nbr', 'family'])['sales'].sum().reset_index()

# Find the maximum sales for each store in each state
max_sales_by_store_state_family = sales_by_state_store_family.groupby(['state', 'store_nbr']).apply(lambda x: x.loc[x['sales'].idxmax()]).reset_index(drop=True)

# Plotting
fig, ax = plt.subplots(figsize=(12, 8))

# Iterate over each state
for state, data in max_sales_by_store_state_family.groupby('state'):
    ax.bar(data['store_nbr'], data['sales'], label=state)

# Set labels and title
ax.set_xlabel('Store Number')
ax.set_ylabel('Maximum Sales')
ax.set_title('Maximum Sales by Product Family for Each Store in Each State')
ax.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
max_sales_by_store_state_family
# Out:
#                              state  store_nbr     family       sales
# 0                            Azuay         37  GROCERY I  6132254.00
# 1                            Azuay         39  GROCERY I  7199976.76
# 2                            Azuay         42  GROCERY I  2337305.57
# 3                          Bolivar         19  GROCERY I  5085657.65
# 4                       Chimborazo         14  GROCERY I  4463305.51
# 5                         Cotopaxi         12  GROCERY I  4208523.91
# 6                         Cotopaxi         13  GROCERY I  4570080.78
# 7                           El Oro         40  GROCERY I  7272900.94
# 8                           El Oro         41  GROCERY I  4892960.00
# 9                       Esmeraldas         43  GROCERY I  5552270.47
# 10                          Guayas         24  GROCERY I  6343142.00
# 11                          Guayas         26  GROCERY I  2720338.00
# 12                          Guayas         27  GROCERY I  5357934.00
# ...

# %% [markdown]
# ##Which store  produce which family the most?

# %%
# Group the DataFrame by 'store_nbr' and 'product_family', and aggregate by sales
sales_by_store_family = merged_df1.groupby(['store_nbr', 'family'])['sales'].sum().reset_index()

# Find the product family with the maximum sales for each store
max_sales_by_store_family = sales_by_store_family.groupby('store_nbr').apply(lambda x: x.loc[x['sales'].idxmax()]).reset_index(drop=True)

# Display the result
print(max_sales_by_store_family[['store_nbr', 'family', 'sales']])
# Out:
#     store_nbr     family       sales
# 0           1  GROCERY I  3743823.00
# 1           2  GROCERY I  6591703.80
# 2           3  GROCERY I 12970467.97
# 3           4  GROCERY I  5636343.59
# 4           5  GROCERY I  5262681.66
# 5           6  GROCERY I  7806646.17
# 6           7  GROCERY I  6247974.00
# 7           8  GROCERY I  7909966.00
# 8           9  GROCERY I 10353098.96
# 9          10  GROCERY I  4126220.17
# 10         11  GROCERY I 11044948.46
# 11         12  GROCERY I  4208523.91
# 12         13  GROCERY I  4570080.78
# 13         14  GROCERY I  4463305.51
# 14         15  GROCERY I  4578222.11
# 15         16  GROCERY I  4307272.25
# 16         17  GROCERY I  6453635.22
# 17         18  GROCERY I  4138689.34
# 18         19  GROCERY I  5085657.65
# 19         20  GROCERY I  4785023.90
# 20         21  GROCERY I  3162815.93
# 21         22  GROCERY I  1570262.31
# 22         23  GROCERY I  3339714.00
# 23         24  GROCERY I  6343142.00
# ...

# %% [markdown]
# ##Which product family  produce by which store the most?

# %%
# Group the DataFrame by 'store_nbr' and 'product_family', and aggregate by sales
sales_by_store_family = merged_df1.groupby(['store_nbr', 'family'])['sales'].sum().reset_index()

# Find the store with the maximum sales for each product family
max_sales_by_product_family = sales_by_store_family.groupby('family').apply(lambda x: x.loc[x['sales'].idxmax()]).reset_index(drop=True)

# Display the result
print(max_sales_by_product_family[['store_nbr', 'family', 'sales']])
# Out:
#     store_nbr                      family       sales
# 0          44                  AUTOMOTIVE    31780.00
# 1          15                   BABY CARE     1580.00
# 2          47                      BEAUTY    20653.00
# 3          44                   BEVERAGES 13417859.00
# 4          47                       BOOKS      581.00
# 5          44                BREAD/BAKERY  2333058.28
# 6           3                 CELEBRATION    48450.00
# 7          44                    CLEANING  4308260.00
# 8          44                       DAIRY  4277954.00
# 9          46                        DELI  1362965.68
# 10         44                        EGGS  1091864.00
# 11         44                FROZEN FOODS  1021094.49
# 12         44                   GROCERY I 16386055.04
# 13         45                  GROCERY II   139536.00
# 14         44                    HARDWARE     7034.00
# 15         44          HOME AND KITCHEN I   134822.00
# ...

# %% [markdown]
# ##How many stores carry each product family?

# %%
# Group the DataFrame by 'product_family' and count the number of unique stores
num_stores_by_product_family = merged_df1.groupby('family')['store_nbr'].nunique().reset_index()

num_stores_by_product_family
# Out:
#                         family  store_nbr
# 0                   AUTOMOTIVE         54
# 1                    BABY CARE         42
# 2                       BEAUTY         54
# 3                    BEVERAGES         54
# 4                        BOOKS         26
# 5                 BREAD/BAKERY         54
# 6                  CELEBRATION         54
# 7                     CLEANING         54
# 8                        DAIRY         54
# 9                         DELI         54
# 10                        EGGS         54
# 11                FROZEN FOODS         54
# 12                   GROCERY I         54
# 13                  GROCERY II         54
# 14                    HARDWARE         54
# 15          HOME AND KITCHEN I         54
# 16         HOME AND KITCHEN II         54
# 17             HOME APPLIANCES         54
# 18                   HOME CARE         54
# 19                  LADIESWEAR         44
# 20             LAWN AND GARDEN         51
# ...

# %% [markdown]
# ##How many stores in each state carry each product family?

# %%
num_stores_by_state_and_product_family = merged_df1.groupby(['state', 'family'])['store_nbr'].nunique().reset_index()

num_stores_by_state_and_product_family
# Out:
#           state                      family  store_nbr
# 0         Azuay                  AUTOMOTIVE          3
# 1         Azuay                   BABY CARE          3
# 2         Azuay                      BEAUTY          3
# 3         Azuay                   BEVERAGES          3
# 4         Azuay                       BOOKS          2
# ..          ...                         ...        ...
# 512  Tungurahua                     POULTRY          2
# 513  Tungurahua              PREPARED FOODS          2
# 514  Tungurahua                     PRODUCE          2
# 515  Tungurahua  SCHOOL AND OFFICE SUPPLIES          2
# 516  Tungurahua                     SEAFOOD          2
#
# [517 rows x 3 columns]

# %%
# Pivot the DataFrame to get states as rows, product families as columns, and count of stores as values
pivot_df = num_stores_by_state_and_product_family.pivot(index='state', columns='family', values='store_nbr')

# Plot the heatmap
plt.figure(figsize=(14, 8))
sns.heatmap(pivot_df, cmap='YlGnBu', linewidths=0.5, linecolor='black', annot=True, fmt='g')
plt.title('Number of Stores by State and Product Family')
plt.xlabel('Product Family')
plt.ylabel('State')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Part 3. Holidays
# ##Average sales according to the Holiday Type

# %%
import seaborn as sns

# Convert the 'date' column in df_holidays to datetime
df_holidays['date'] = pd.to_datetime(df_holidays['date'])

# Merge the holiday data with the sales data
merged_data = pd.merge(df_train1, df_holidays, how='left', on='date')

# Group by store type and holiday type, then calculate the average sales for each group
sales_by_store_type_and_holiday = merged_data.groupby(['type', 'locale_name'])['sales'].mean().reset_index()

# Plot the average sales for each store type and holiday type
plt.figure(figsize=(14, 6))
sns.barplot(x='type', y='sales', hue='locale_name', data=sales_by_store_type_and_holiday)
plt.title('Average Sales by Holiday Type')
plt.xlabel('Holiday Type')
plt.ylabel('Average Sales')
plt.xticks(rotation=45)
plt.legend(title='Holiday Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Check there is records of sales during the holidays?

# %%
# Merge sales data with holidays data
merged_data = pd.merge(df_train1, df_holidays, how='left', on='date')

# Filter sales data for holidays
sales_on_holidays = merged_data[merged_data['type'] != 'Work Day']

# Check if there are any sales on holidays
if sales_on_holidays.empty:
    print("There are no sales recorded on holidays.")
else:
    print("There are sales recorded on holidays.")
# Out:
# There are sales recorded on holidays.

# %%
sales_on_holidays
# Out:
#               date  store_nbr                      family   sales  year  \
# 0       2013-01-01         25                      BEAUTY    2.00  2013
# 1       2013-01-01         25                   BEVERAGES  810.00  2013
# 2       2013-01-01         25                BREAD/BAKERY  180.59  2013
# 3       2013-01-01         25                    CLEANING  186.00  2013
# 4       2013-01-01         25                       DAIRY  143.00  2013
# ...            ...        ...                         ...     ...   ...
# 2100602 2017-08-15          9                     POULTRY  438.13  2017
# 2100603 2017-08-15          9              PREPARED FOODS  154.55  2017
# 2100604 2017-08-15          9                     PRODUCE 2419.73  2017
# 2100605 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES  121.00  2017
# 2100606 2017-08-15          9                     SEAFOOD   16.00  2017
#
#          day_of_week  weekend  week     type    locale locale_name  \
# ...

# %% [markdown]
# ## analyze daily sales vs holidays sales

# %%
# Group the data by date and calculate the total sales for each day
daily_sales = df_train1.groupby('date')['sales'].sum().reset_index()

# Identify the holidays
holidays = df_holidays[df_holidays['type'] == 'Holiday']['date'].unique()

# Create a new column to mark holidays
daily_sales['is_holiday'] = daily_sales['date'].isin(holidays)

# Group the data by holiday status and calculate the total sales for each category
sales_by_holiday_status = daily_sales.groupby('is_holiday')['sales'].sum()

# Plot the results
plt.figure(figsize=(10, 6))
sales_by_holiday_status.plot(kind='bar', color=['lightgreen', 'skyblue'])

# Add labels and title
plt.xlabel('Holiday Status')
plt.ylabel('Total Sales')
plt.title('Total Daily Sales vs. Holiday Sales')

# Customize x-axis labels
plt.xticks([0, 1], ['Non-Holiday', 'Holiday'], rotation=0)

# Show plot
plt.show()

# %% [markdown]
# ## Analyze the 'daily_avg_sales' series to see if there are differences in sales on holidays compared to regular days?

# %%
from scipy.stats import ttest_ind
# Group the data by holiday status and calculate the average daily sales for each category
avg_sales_by_holiday_status = daily_sales.groupby('is_holiday')['sales'].mean()

# Extract the daily average sales for holidays and non-holidays
avg_sales_holidays = daily_sales[daily_sales['is_holiday']]['sales']
avg_sales_workdays = daily_sales[~daily_sales['is_holiday']]['sales']

# Perform a t-test to compare the mean sales between holidays and workdays
t_stat, p_value = ttest_ind(avg_sales_holidays, avg_sales_workdays)

# Define significance level
alpha = 0.05

# Print the results
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in average daily sales between holidays and workdays.")
else:
    print("Fail to reject the null hypothesis. There's no significant difference in average daily sales between holidays and workdays.")
# Out:
# Fail to reject the null hypothesis. There's no significant difference in average daily sales between holidays and workdays.

# %% [markdown]
# ##Compare holiday average sales and non-holiday average sales to see the average difference in sales during holidays.
#
# ###Intepretations: The output indicates that, on average, there is a difference of approximately 12.06 units in sales between holidays and non-holidays. (the average difference is positive, it implies that sales are higher during holidays compared to non-holidays)

# %%
# Calculate average sales during holidays
avg_sales_holidays = merged_data[merged_data['type'] == 'Holiday']['sales'].mean()

# Calculate average sales during non-holidays
avg_sales_non_holidays = merged_data[merged_data['type'] != 'Holiday']['sales'].mean()

# Calculate the difference in average sales between holidays and non-holidays
avg_difference_sales = avg_sales_holidays - avg_sales_non_holidays
print("Average difference in sales during holidays compared to non-holidays:", avg_difference_sales)
# Out:
# Average difference in sales during holidays compared to non-holidays: 12.056693813957395

# %%
df_train
# Out:
#               id       date  store_nbr                      family   sales  \
# 0              0 2013-01-01          1                  AUTOMOTIVE    0.00
# 1              1 2013-01-01          1                   BABY CARE    0.00
# 2              2 2013-01-01          1                      BEAUTY    0.00
# 3              3 2013-01-01          1                   BEVERAGES    0.00
# 4              4 2013-01-01          1                       BOOKS    0.00
# ...          ...        ...        ...                         ...     ...
# 3000883  3000883 2017-08-15          9                     POULTRY  438.13
# 3000884  3000884 2017-08-15          9              PREPARED FOODS  154.55
# 3000885  3000885 2017-08-15          9                     PRODUCE 2419.73
# 3000886  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES  121.00
# 3000887  3000887 2017-08-15          9                     SEAFOOD   16.00
#
#          onpromotion
# 0                  0
# 1                  0
# ...

# %% [markdown]
# ##Find the maximum sales achieved on holidays by product_family?

# %%
# Filter the DataFrame to include only rows where sales occurred on holidays
holiday_sales_df = df_train[(df_train['date'].isin(df_holidays['date'])) & (df_train['sales'] > 0)]

# Group by product_family and find the maximum sales within each family
max_sales_by_family = holiday_sales_df.groupby('family')['sales'].max().reset_index()

# Sort the DataFrame by maximum sales in descending order
max_sales_by_family_sorted = max_sales_by_family.sort_values(by='sales', ascending=False)

max_sales_by_family_sorted
# Out:
#                         family     sales
# 12                   GROCERY I 124717.00
# 24                       MEATS  89576.36
# 3                    BEVERAGES  25413.00
# 30                     PRODUCE  17449.59
# 11                FROZEN FOODS  14541.55
# 7                     CLEANING  10801.00
# 25               PERSONAL CARE   7504.00
# 28                     POULTRY   6308.21
# 8                        DAIRY   5636.00
# 5                 BREAD/BAKERY   4551.30
# 22            LIQUOR,WINE,BEER   3395.00
# 10                        EGGS   3010.00
# 13                  GROCERY II   2797.00
# 18                   HOME CARE   2504.00
# 9                         DELI   1884.85
# 6                  CELEBRATION   1783.00
# 15          HOME AND KITCHEN I   1716.00
# 21                    LINGERIE   1059.00
# 29              PREPARED FOODS    912.57
# 16         HOME AND KITCHEN II    894.00
# 31  SCHOOL AND OFFICE SUPPLIES    757.00
# 20             LAWN AND GARDEN    712.00
# ...

# %%
# Plot the maximum sales achieved on holidays by product family
plt.figure(figsize=(12, 8))
plt.barh(max_sales_by_family_sorted['family'], max_sales_by_family_sorted['sales'], color='skyblue')
plt.xlabel('Maximum Sales')
plt.ylabel('Product Family')
plt.title('Maximum Sales Achieved on Holidays by Product Family')
plt.gca().invert_yaxis()  # Invert y-axis to display the product families with the highest sales at the top
plt.show()

# %%
# Filter the DataFrame to include only rows where sales occurred on non-holidays
non_holiday_sales_df = df_train[~(df_train['date'].isin(df_holidays['date'])) & (df_train['sales'] > 0)]

# Group by product_family and find the maximum sales within each family
max_sales_by_family_non_holiday = non_holiday_sales_df.groupby('family')['sales'].max().reset_index()

# Sort the DataFrame by maximum sales in descending order
max_sales_by_family_non_holiday_sorted = max_sales_by_family_non_holiday.sort_values(by='sales', ascending=False)

max_sales_by_family_non_holiday_sorted
# Out:
#                         family    sales
# 12                   GROCERY I 40351.46
# 3                    BEVERAGES 21928.00
# 30                     PRODUCE 17850.62
# 11                FROZEN FOODS 12646.77
# 28                     POULTRY 12143.20
# 24                       MEATS 11609.56
# 7                     CLEANING 11377.00
# 8                        DAIRY  5364.00
# 22            LIQUOR,WINE,BEER  4821.00
# 5                 BREAD/BAKERY  3606.89
# 25               PERSONAL CARE  3458.00
# 10                        EGGS  3110.00
# 13                  GROCERY II  2931.00
# 18                   HOME CARE  2214.00
# 9                         DELI  2118.32
# 15          HOME AND KITCHEN I  1935.00
# 16         HOME AND KITCHEN II  1568.00
# 31  SCHOOL AND OFFICE SUPPLIES  1332.00
# 6                  CELEBRATION  1306.00
# 29              PREPARED FOODS   892.57
# 20             LAWN AND GARDEN   312.00
# 32                     SEAFOOD   274.44
# ...

# %%
# Plot the maximum sales achieved on non-holidays by product family
plt.figure(figsize=(12, 8))
plt.barh(max_sales_by_family_non_holiday_sorted['family'], max_sales_by_family_non_holiday_sorted['sales'], color='lightgreen')
plt.xlabel('Maximum Sales')
plt.ylabel('Product Family')
plt.title('Maximum Sales Achieved on Non-Holidays by Product Family')
plt.gca().invert_yaxis()  # Invert y-axis to display the product families with the highest sales at the top
plt.show()

# %%
# Find the maximum sales achieved on holidays
max_sales_on_holidays = sales_on_holidays['sales'].max()

# Filter sales data for holidays
sales_on_workdays = merged_data[merged_data['type'] == 'Work Day']

# Find the maximum sales achieved on workdays
max_sales_on_workdays = sales_on_workdays['sales'].max()

# Print the maximum sales achieved on holidays and workdays
print("Maximum sales on holidays:", max_sales_on_holidays)
print("Maximum sales on workdays:", max_sales_on_workdays)
# Out:
# Maximum sales on holidays: 124717.0
# Maximum sales on workdays: 18222.0

# %%
import matplotlib.pyplot as plt

# Create a bar plot for maximum sales on holidays and workdays
plt.figure(figsize=(8, 6))
plt.bar(['Holidays', 'Workdays'], [max_sales_on_holidays, max_sales_on_workdays], color=['skyblue', 'lightgreen'])
plt.title('Comparison of Maximum Sales on Holidays and Workdays')
plt.xlabel('Day Type')
plt.ylabel('Maximum Sales')
plt.show()

# %%
merged_df1
# Out:
#          store_nbr       city      state type  cluster       date  \
# 0                1      Quito  Pichincha    D       13 2013-01-02
# 1                1      Quito  Pichincha    D       13 2013-01-02
# 2                1      Quito  Pichincha    D       13 2013-01-02
# 3                1      Quito  Pichincha    D       13 2013-01-02
# 4                1      Quito  Pichincha    D       13 2013-01-02
# ...            ...        ...        ...  ...      ...        ...
# 2061753         54  El Carmen     Manabi    C        3 2017-08-15
# 2061754         54  El Carmen     Manabi    C        3 2017-08-15
# 2061755         54  El Carmen     Manabi    C        3 2017-08-15
# 2061756         54  El Carmen     Manabi    C        3 2017-08-15
# 2061757         54  El Carmen     Manabi    C        3 2017-08-15
#
#                           family   sales
# 0                     AUTOMOTIVE    2.00
# 1                         BEAUTY    2.00
# 2                      BEVERAGES 1091.00
# ...
