# %% [markdown]
# # Step 1. Preprocessing dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from pmdarima import auto_arima
from scipy import stats

# %%
df = pd.read_csv('train.csv', header = 0)
df.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
# Convert 'date' column to datetime type if it's not already
df['date'] = pd.to_datetime(df['date'])

# Group by 'date' and calculate sum of 'sales' for each day
df = df.groupby('date')['sales'].sum()

print(df.head())
print(df.shape)
# Out:
# date
# 2013-01-01      2511.618999
# 2013-01-02    496092.417944
# 2013-01-03    361461.231124
# 2013-01-04    354459.677093
# 2013-01-05    477350.121229
# Name: sales, dtype: float64
# (1684,)

# %%
df.info()
df.plot()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 1684 entries, 2013-01-01 to 2017-08-15
# Series name: sales
# Non-Null Count  Dtype
# --------------  -----
# 1684 non-null   float64
# dtypes: float64(1)
# memory usage: 26.3 KB
# <Axes: xlabel='date'>

# %%
df = np.log(df) # don't forget to transform the data back when making real predictions
df.plot()
# Out:
# <Axes: xlabel='date'>

# %%
# Convert the index (date) to datetime if not already
df.index = pd.to_datetime(df.index)

# Calculate rolling mean (moving average) to remove seasonality
window = 30  # You can adjust the window size according to your data frequency (for daily data with weekly seasonality-7, for monthly seasonality-30)
df_sa = df.rolling(window=window, min_periods=1, center=True).mean()

# Calculate the seasonal pattern (difference between original and seasonally adjusted data)
seasonal_pattern = df - df_sa

# Plot both seasonally adjusted and unadjusted data
plt.figure(figsize=(10, 6))
plt.plot(df.index, df, label='Original')
plt.plot(df.index, df_sa, label='Seasonally Adjusted (Moving Average)')
plt.title('Daily Sales: Original vs Seasonally Adjusted')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
# Ensure df_sa has a DateTimeIndex
df_sa.index = pd.to_datetime(df_sa.index)

# Create a mask to select all but the last 30 entries
msk = df_sa.index < df_sa.index[-30]

# Apply the mask to split the data into train and test sets
df_train = df_sa[msk].copy()
df_test = df_sa[~msk].copy()

# %%
df_train.head()
# Out:
# date
# 2013-01-01    12.464525
# 2013-01-02    12.477423
# 2013-01-03    12.478567
# 2013-01-04    12.485233
# 2013-01-05    12.511129
# Name: sales, dtype: float64

# %%
df_test.head()
# Out:
# date
# 2017-07-17    13.649258
# 2017-07-18    13.640221
# 2017-07-19    13.641617
# 2017-07-20    13.637154
# 2017-07-21    13.636496
# Name: sales, dtype: float64

# %% [markdown]
# # Step 2. Stationarity of the Time Series Data

# %% [markdown]
# ## Method 1. ACF and PACF

# %%
lag_number = 150

# %%
acf_original = plot_acf(df_train, lags=lag_number)
pacf_original = plot_pacf(df_train, lags=lag_number)

# %% [markdown]
# ## Method 2. ADF

# %%
# Applying the Augmented Dickey-Fuller (ADF) test
adf_result = adfuller(df_train)

# Retrieving and displaying the test statistics and p-value
adf_statistic = adf_result[0]
p_value = adf_result[1]
print("ADF Statistic:", adf_statistic)
print("p-value:", p_value)
# Out:
# ADF Statistic: -1.8326131902558633
# p-value: 0.36439453081695833

# %%
# Compute the first difference of the seasonally adjusted sales data
df_train_diff = df_train.diff().dropna()
df_train_diff.plot()
# Out:
# <Axes: xlabel='date'>

# %%
adf_test = adfuller(df_train_diff)
print(f'p-value: {adf_test[1]}')
# Out:
# p-value: 2.7283398136356392e-14

# %% [markdown]
# # Step 3. Fit the model

# %%
stepwise_fit = auto_arima(df_train_diff, trace=True, suppress_warnings=True)
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-9197.636, Time=0.38 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-9080.230, Time=0.08 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-9172.663, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-9194.490, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-9078.639, Time=0.04 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-9193.360, Time=0.20 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-9200.866, Time=0.27 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-9195.398, Time=0.17 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-9202.337, Time=0.18 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=-9200.633, Time=0.12 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=-9198.419, Time=0.36 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-9201.411, Time=0.16 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0] intercept
# Total fit time: 2.128 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1653
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                4605.168
# Date:                Sat, 18 May 2024   AIC                          -9202.337
# Time:                        01:28:18   BIC                          -9180.695
# Sample:                             0   HQIC                         -9194.314
#                                - 1653
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0006      0.000      1.689      0.091      -0.000       0.001
# ar.L1          0.2682      0.011     24.838      0.000       0.247       0.289
# ar.L2         -0.1379      0.021     -6.505      0.000      -0.179      -0.096
# sigma2         0.0002   1.83e-06    121.610      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):            118040.99
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.82   Skew:                             0.61
# Prob(H) (two-sided):                  0.02   Kurtosis:                        44.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
df_train_diff.head()
# Out:
# date
# 2013-01-02    0.012898
# 2013-01-03    0.001144
# 2013-01-04    0.006666
# 2013-01-05    0.025895
# 2013-01-06    0.026511
# Name: sales, dtype: float64

# %%
# Visualize the time series
plt.figure(figsize=(10, 6))
plt.plot(df_train_diff, marker='o', linestyle='-')
plt.title('Time Series of Sales Differences')
plt.xlabel('Date')
plt.ylabel('Sales Difference')
plt.grid(True)
plt.show()

# Calculate the Interquartile Range (IQR)
Q1 = df_train_diff.quantile(0.25)
Q3 = df_train_diff.quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df_train_diff[(df_train_diff < lower_bound) | (df_train_diff > upper_bound)]
print("Outliers:")
print(outliers)

# Remove outliers
df_train_diff_no_outliers = df_train_diff[~((df_train_diff < lower_bound) | (df_train_diff > upper_bound))]

# Visualize the time series without outliers
plt.figure(figsize=(10, 6))
plt.plot(df_train_diff_no_outliers, marker='o', linestyle='-')
plt.title('Time Series of Sales Differences (without outliers)')
plt.xlabel('Date')
plt.ylabel('Sales Difference')
plt.grid(True)
plt.show()
# Out:
# Outliers:
# date
# 2013-01-17    0.156071
# 2013-12-17   -0.146551
# 2014-01-17    0.139246
# 2014-12-17   -0.138625
# 2015-01-17    0.131303
# 2015-12-17   -0.131828
# 2016-01-17    0.139919
# 2016-12-17   -0.141531
# 2017-01-17    0.138842
# Name: sales, dtype: float64

# %%
stepwise_fit = auto_arima(df_train_diff_no_outliers, trace=True, suppress_warnings=True)
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-10944.125, Time=1.06 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-9996.965, Time=0.08 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-10477.401, Time=0.24 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-10894.913, Time=0.20 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-9993.967, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-10984.632, Time=0.98 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=-10938.153, Time=0.53 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-10918.334, Time=0.44 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=-10948.387, Time=1.04 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=-11016.883, Time=0.93 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=-11014.860, Time=1.17 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=-11028.847, Time=1.55 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=-11054.929, Time=1.55 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=-11103.803, Time=1.18 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=-11105.666, Time=1.32 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=-10996.564, Time=1.23 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=-11569.932, Time=1.36 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=-10998.991, Time=1.32 sec
#  ARIMA(5,0,3)(0,0,0)[0] intercept   : AIC=-12221.604, Time=1.83 sec
#  ARIMA(5,0,2)(0,0,0)[0] intercept   : AIC=-11101.629, Time=1.74 sec
#  ARIMA(5,0,4)(0,0,0)[0] intercept   : AIC=-12616.021, Time=1.94 sec
#  ARIMA(4,0,4)(0,0,0)[0] intercept   : AIC=-11562.637, Time=1.65 sec
#  ARIMA(5,0,5)(0,0,0)[0] intercept   : AIC=-12671.513, Time=1.86 sec
#  ARIMA(4,0,5)(0,0,0)[0] intercept   : AIC=-11332.485, Time=2.00 sec
#  ARIMA(5,0,5)(0,0,0)[0]             : AIC=-12673.361, Time=1.60 sec
#  ARIMA(4,0,5)(0,0,0)[0]             : AIC=-11267.867, Time=1.34 sec
#  ARIMA(5,0,4)(0,0,0)[0]             : AIC=-12616.311, Time=1.32 sec
#  ARIMA(4,0,4)(0,0,0)[0]             : AIC=-11820.661, Time=1.19 sec
#
# Best model:  ARIMA(5,0,5)(0,0,0)[0]
# Total fit time: 32.722 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1644
# Model:               SARIMAX(5, 0, 5)   Log Likelihood                6347.681
# Date:                Sat, 18 May 2024   AIC                         -12673.361
# Time:                        01:29:39   BIC                         -12613.908
# Sample:                             0   HQIC                        -12651.314
#                                - 1644
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.6844      0.011    146.933      0.000       1.662       1.707
# ar.L2         -2.1162      0.013   -165.085      0.000      -2.141      -2.091
# ar.L3          2.0626      0.017    117.901      0.000       2.028       2.097
# ar.L4         -1.6604      0.013   -124.049      0.000      -1.687      -1.634
# ar.L5          0.8648      0.011     75.935      0.000       0.842       0.887
# ma.L1         -1.0465      0.021    -48.838      0.000      -1.088      -1.004
# ma.L2          1.2904      0.027     47.211      0.000       1.237       1.344
# ma.L3         -0.9676      0.033    -28.969      0.000      -1.033      -0.902
# ma.L4          0.7129      0.028     25.684      0.000       0.658       0.767
# ma.L5         -0.1651      0.023     -7.290      0.000      -0.210      -0.121
# sigma2      2.555e-05   6.76e-07     37.796      0.000    2.42e-05    2.69e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):               245.02
# Prob(Q):                              0.70   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.88   Skew:                            -0.06
# Prob(H) (two-sided):                  0.15   Kurtosis:                         4.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## Check whether residuals are normally distributed or not?

# %%
# Plot Histogram
plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
sns.histplot(df_train_diff_no_outliers, kde=True, color='blue', bins=30)
plt.title('Histogram of Residuals')
plt.xlabel('Residuals')
plt.ylabel('Frequency')

# Plot Q-Q plot
plt.subplot(1, 3, 2)
stats.probplot(df_train_diff_no_outliers, dist="norm", plot=plt)
plt.title('Q-Q Plot')

# Plot Density Plot
plt.subplot(1, 3, 3)
sns.kdeplot(df_train_diff_no_outliers, shade=True, color='blue')
plt.title('Density Plot of Residuals')
plt.xlabel('Residuals')
plt.ylabel('Density')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_12136\3366521421.py:17: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_train_diff_no_outliers, shade=True, color='blue')

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(df_train_diff_no_outliers, order=(5,0,5))
model_fit = model.fit()
print(model_fit.summary())
# Out:
# C:\Users\Welcome\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Welcome\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Welcome\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  sales   No. Observations:                 1644
# Model:                 ARIMA(5, 0, 5)   Log Likelihood                6347.749
# Date:                Sat, 18 May 2024   AIC                         -12671.498
# Time:                        01:29:45   BIC                         -12606.640
# Sample:                             0   HQIC                        -12647.447
#                                - 1644
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.001      1.140      0.254      -0.001       0.002
# ar.L1          1.6782      0.012    144.669      0.000       1.655       1.701
# ar.L2         -2.1105      0.013   -162.572      0.000      -2.136      -2.085
# ar.L3          2.0559      0.018    115.414      0.000       2.021       2.091
# ar.L4         -1.6556      0.014   -121.642      0.000      -1.682      -1.629
# ar.L5          0.8650      0.012     74.763      0.000       0.842       0.888
# ma.L1         -1.0466      0.022    -47.771      0.000      -1.090      -1.004
# ma.L2          1.2922      0.028     46.058      0.000       1.237       1.347
# ma.L3         -0.9732      0.034    -28.471      0.000      -1.040      -0.906
# ma.L4          0.7149      0.029     25.044      0.000       0.659       0.771
# ma.L5         -0.1831      0.023     -7.794      0.000      -0.229      -0.137
# sigma2      2.611e-05   7.05e-07     37.011      0.000    2.47e-05    2.75e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.49   Jarque-Bera (JB):               243.39
# Prob(Q):                              0.48   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.88   Skew:                            -0.07
# Prob(H) (two-sided):                  0.14   Kurtosis:                         4.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\Welcome\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# # Step 4: Forecast

# %%
import matplotlib.pyplot as plt
residuals = model_fit.resid[1:]
fig, ax = plt.subplots(1,2)
residuals.plot(title='Residuals', ax=ax[0])
residuals.plot(title='Density', kind='kde', ax=ax[1])
plt.show()

# %%
acf_res = plot_acf(residuals)

pacf_res = plot_pacf(residuals)

# %%
df.head()
# Out:
# date
# 2013-01-01     7.828683
# 2013-01-02    13.114518
# 2013-01-03    12.797910
# 2013-01-04    12.778350
# 2013-01-05    13.076006
# Name: sales, dtype: float64

# %%
df_train.tail()
# Out:
# date
# 2017-07-12    13.628647
# 2017-07-13    13.627536
# 2017-07-14    13.631933
# 2017-07-15    13.648351
# 2017-07-16    13.659584
# Name: sales, dtype: float64

# %%
df.head()
# Out:
# date
# 2013-01-01 00:00:00     7.828683
# 2013-01-02 00:00:00    13.114518
# 2013-01-03 00:00:00     12.79791
# 2013-01-04 00:00:00     12.77835
# 2013-01-05 00:00:00    13.076006
# Name: sales, dtype: object

# %%
df_test.head()
# Out:
# date
# 2017-07-17    13.649258
# 2017-07-18    13.640221
# 2017-07-19    13.641617
# 2017-07-20    13.637154
# 2017-07-21    13.636496
# Name: sales, dtype: float64

# %%
forecast_test = model_fit.forecast(len(df_test))

df['forecast_manual'] = [None]*len(df_train) + list(forecast_test)

df.plot()
# Out:
# C:\Users\Welcome\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\Welcome\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[124], line 5
#       1 forecast_test = model_fit.forecast(len(df_test))
#       3 df['forecast_manual'] = [None]*len(df_train) + list(forecast_test)
# ----> 5 df.plot()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_matplotlib\core.py:451, in MPLPlot.generate(self)
#     449 def generate(self) -> None:
#     450     self._args_adjust()
# --> 451     self._compute_plot_data()
#     452     self._setup_subplots()
#     453     self._make_plot()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_matplotlib\core.py:636, in MPLPlot._compute_plot_data(self)
#     634 # no non-numeric frames or series allowed
#     635 if is_empty:
# --> 636     raise TypeError("no numeric data to plot")
#     638 self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot
